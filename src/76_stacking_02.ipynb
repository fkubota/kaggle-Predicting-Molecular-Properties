# %% [markdown]
# # Overview
# - スタッキングを試してみる

# %% [markdown]
# # Import everything I need :)

# %%
import warnings
warnings.filterwarnings('ignore')
import time
import multiprocessing
import glob
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn import linear_model
import lightgbm as lgb
from fastprogress import progress_bar

# %% [markdown]
# # Preparation

# %%
nb = 76
isSmallSet = False
length = 100000
model_name = 'lgb'

# %%
pd.set_option('display.max_columns', 200)

# %%
file_path = '../input/champs-scalar-coupling/'
glob.glob(file_path + '*')
# Out:
# ['../input/champs-scalar-coupling/magnetic_shielding_tensors.csv',
#  '../input/champs-scalar-coupling/structures.csv',
#  '../input/champs-scalar-coupling/mulliken_charges.csv',
#  '../input/champs-scalar-coupling/structures.zip',
#  '../input/champs-scalar-coupling/train_ob_charges_V7EstimatioofMullikenChargeswithOpenBabel.csv',
#  '../input/champs-scalar-coupling/test_ob_charges_V7EstimatioofMullikenChargeswithOpenBabel.csv',
#  '../input/champs-scalar-coupling/scalar_coupling_contributions.csv',
#  '../input/champs-scalar-coupling/nb33_test_dist-interaction.csv',
#  '../input/champs-scalar-coupling/train.csv',
#  '../input/champs-scalar-coupling/nb47_fc_test.csv',
#  '../input/champs-scalar-coupling/nb33_train_dist-interaction.csv',
#  '../input/champs-scalar-coupling/test.csv',
#  '../input/champs-scalar-coupling/sample_submission.csv',
#  '../input/champs-scalar-coupling/nb29_fc_test_feature.csv',
#  '../input/champs-scalar-coupling/dipole_moments.csv',
#  '../input/champs-scalar-coupling/nb47_fc_train.csv',
#  '../input/champs-scalar-coupling/potential_energy.csv',
#  '../input/champs-scalar-coupling/nb29_fc_train_feature.csv']

# %%
# train
path = file_path + 'train.csv'
if isSmallSet:
    train = pd.read_csv(path) [:length]
else:
    train = pd.read_csv(path)
    
type_train = train.type.values

# %%
# train
path = file_path + 'test.csv'
if isSmallSet:
    test = pd.read_csv(path) [:length]
else:
    test = pd.read_csv(path)
    
type_test = test.type.values

# %% [markdown]
# ## myFunc
# **metrics**

# %%
def kaggle_metric(df, preds):
    df["prediction"] = preds
    maes = []
    for t in df.type.unique():
        y_true = df[df.type==t].scalar_coupling_constant.values
        y_pred = df[df.type==t].prediction.values
        mae = np.log(mean_absolute_error(y_true, y_pred))
        maes.append(mae)
    return np.mean(maes)

# %% [markdown]
# # Stacking

# %%
path_list = [
'nb54_{}_random_forest_regressor_-1.45569.csv',
'nb57_{}_lasso_-1.07263.csv',
'nb60_{}_lgb_-1.5330660525700779.csv',
'nb63_{}_ridge_-1.37017.csv',
'nb69_{}_ridge_-1.24324.csv',
'nb69_{}_ridge_-1.24325.csv',
'nb70_{}_ridge_-1.18702.csv',
'nb70_{}_ridge_-1.18703.csv',
'nb71_{}_lasso_-1.17648.csv',
]

# %%
# oof
oofs = []
for path in path_list:
    if isSmallSet:
        df = pd.read_csv('./../output/' + path.format('oof'))[:length]
    else:
        df = pd.read_csv('./../output/' + path.format('oof'))
    oofs.append(df)

# %%
# sub
subs = []
for path in path_list:
    if isSmallSet:
        df = pd.read_csv('./../output/' + path.format('submission')).drop(['id'], axis=1)[:length]
    else:
        df = pd.read_csv('./../output/' + path.format('submission')).drop(['id'], axis=1)
    subs.append(df)

# %% [markdown]
# # Create train, test data

# %% [markdown]
# LabelEncode
# - `type`   = {2JHC, ...}

# %%
lbl = LabelEncoder()
lbl.fit(list(type_train) + list(type_test))
type_train_lbl = lbl.transform(type_train)
type_test_lbl = lbl.transform(type_test)

# %%
y = train.scalar_coupling_constant
X = pd.concat(oofs, axis=1)
X = pd.DataFrame(X.values, columns=path_list)
X_test = pd.concat(subs, axis=1)
X_test = pd.DataFrame(X_test.values, columns=path_list)

# %% [markdown]
# # Training model

# %% [markdown]
# **params**

# %%
# Configuration
TARGET = 'scalar_coupling_constant'
CAT_FEATS = []
N_ESTIMATORS = 1500
VERBOSE = 100
EARLY_STOPPING_ROUNDS = 200
RANDOM_STATE = 529
METRIC = mean_absolute_error
LEANING_RATE = 0.01 
N_JOBS = 5

# lightgbm params from nb55
# lgb_params = {'num_leaves': 128,
#           'min_child_samples': 79,
#           'objective': 'regression',
#           'max_depth': 9,
#           'learning_rate': 0.2,
#           "boosting_type": "gbdt",
#           "subsample_freq": 1,
#           "subsample": 0.9,
#           "bagging_seed": 11,
#           "metric": 'mae',
#           "verbosity": -1,
#           'reg_alpha': 0.1,
#           'reg_lambda': 0.3,
#           'colsample_bytree': 1.0
#          }

lgb_params_list =  [
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 1,
  'max_depth': 8,
  'metric': 'mae',
  'min_child_samples': 70,
  'num_leaves': 250,
  'objective': 'regression',
  'reg_alpha': 0.1,
  'reg_lambda': 0.6,
  'subsample': 1,
  'subsample_freq': 1,
  'verbosity': -1},
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 0.8,
  'max_depth': 15,
  'metric': 'mae',
  'min_child_samples': 70,
  'num_leaves': 100,
  'objective': 'regression',
  'reg_alpha': 0.4,
  'reg_lambda': 0.4,
  'subsample': 1,
  'subsample_freq': 1,
  'verbosity': -1},
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 0.8,
  'max_depth': 8,
  'metric': 'mae',
  'min_child_samples': 45,
  'num_leaves': 250,
  'objective': 'regression',
  'reg_alpha': 0.6,
  'reg_lambda': 0.4,
  'subsample': 1,
  'subsample_freq': 1,
  'verbosity': -1},
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 1,
  'max_depth': 15,
  'metric': 'mae',
  'min_child_samples': 20,
  'num_leaves': 250,
  'objective': 'regression',
  'reg_alpha': 0.2,
  'reg_lambda': 0.4,
  'subsample': 0.3,
  'subsample_freq': 1,
  'verbosity': -1},
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 0.8,
  'max_depth': 15,
  'metric': 'mae',
  'min_child_samples': 70,
  'num_leaves': 100,
  'objective': 'regression',
  'reg_alpha': 0.1,
  'reg_lambda': 0.2,
  'subsample': 1,
  'subsample_freq': 1,
  'verbosity': -1},
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 1,
  'max_depth': 8,
  'metric': 'mae',
  'min_child_samples': 20,
  'num_leaves': 100,
  'objective': 'regression',
  'reg_alpha': 0.6,
  'reg_lambda': 0.2,
  'subsample': 1,
  'subsample_freq': 1,
  'verbosity': -1},
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 0.6,
  'max_depth': 15,
  'metric': 'mae',
  'min_child_samples': 100,
  'num_leaves': 250,
  'objective': 'regression',
  'reg_alpha': 0.2,
  'reg_lambda': 0.4,
  'subsample': 1,
  'subsample_freq': 1,
  'verbosity': -1},
 {'bagging_seed': 11,
  'boosting': 'gbdt',
  'colsample_bytree': 1,
  'max_depth': 15,
  'metric': 'mae',
  'min_child_samples': 45,
  'num_leaves': 250,
  'objective': 'regression',
  'reg_alpha': 0.2,
  'reg_lambda': 0.2,
  'subsample': 1,
  'subsample_freq': 1,
  'verbosity': -1}]

# %%
# init

def train_lgb(X, X_test, y, lgb_params, folds,
              verbose, early_stopping_rounds, n_estimators, categorical_feature=None):

    result_dict = {}
    oof = np.zeros(len(X))
    prediction = np.zeros(len(X_test))
    scores = []
    models = []
    feature_importance = pd.DataFrame()
    for fold_n, (train_idx, valid_idx) in enumerate(folds.split(X)):
        print('------------------')
        print(f'- fold{fold_n + 1}' )
        print(f'Fold {fold_n + 1} started at {time.ctime()}')
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y[train_idx], y[valid_idx]
#         from IPython.core.debugger import Pdb; Pdb().set_trace()
        

        # Train the model
        model = lgb.LGBMRegressor(**lgb_params, n_estimators=n_estimators, n_jobs=N_JOBS, learning_rate=LEANING_RATE)
        model.fit(X_train, y_train,
                  eval_set=[(X_train, y_train), (X_valid, y_valid)],
                  verbose=verbose,
                  early_stopping_rounds=early_stopping_rounds,
                  categorical_feature=CAT_FEATS)

        # predict
        y_valid_pred = model.predict(X_valid, num_iteration=model.best_iteration_)   
        y_test_pred = model.predict(X_test)

        oof[valid_idx] = y_valid_pred.reshape(-1,)  # oof: out of folds
        scores.append(mean_absolute_error(y_valid, y_valid_pred))

        prediction += y_test_pred

        # feature_importance
        fold_importance = pd.DataFrame()
        fold_importance['feature'] = X.columns
        fold_importance['importance'] = model.feature_importances_
        fold_importance['fold'] = fold_n + 1
        feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    # result
    prediction /= folds.n_splits
    feature_importance["importance"] /= folds.n_splits
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    result_dict['feature_importance'] = feature_importance


    print('------------------')
    print('====== finish ======')
    print('score list:', scores)
    X['scalar_coupling_constant'] = y
#     cv_score = kaggle_metric(X, oof)
    cv_score = np.log(mean_absolute_error(y, oof))  # kaggle_metric(X, oof)
#     X = X.drop(['scalar_coupling_constant', 'prediction'], axis=1)
    print('CV mean score(group log mae): {0:.4f}'.format(cv_score))
    print('')

    
    return result_dict, cv_score

# %%
n_folds = 6
folds = KFold(n_splits=n_folds, shuffle=True)

# %%
# %%time
# type ごとの学習 

feature_importance  = pd.DataFrame()
X_short = pd.DataFrame({'ind': list(X.index), 'type': type_train, 'oof': [0] * len(X), 'target': y.values})
X_short_test = pd.DataFrame({'ind': list(X_test.index), 'type': type_test, 'prediction': [0] * len(X_test)})
for i, t in enumerate(np.unique(type_train)):
    print('*'*80)
    print(f'Training of type {t}')
    print('*'*80)
    idx = lbl.transform([t])[0]
    lgb_params = lgb_params_list[idx]
    X_t = X.loc[type_train == t]
    X_test_t = X_test.loc[type_test == t]
    y_t = X_short.loc[type_train == t, 'target'].values
#     from IPython.core.debugger import Pdb; Pdb().set_trace()

#     result_dict_lgb3 = train_model_regression(X=X_t, X_test=X_test_t, y=y_t, params=params, folds=folds, model_type='lgb', eval_metric='group_mae', plot_feature_importance=False,
#                                                       verbose=500, early_stopping_rounds=200, n_estimators=3000)
    result_dict, cv_score = train_lgb(X=X_t, X_test=X_test_t, y=y_t, folds=folds, lgb_params=lgb_params,
                            verbose=VERBOSE, early_stopping_rounds=EARLY_STOPPING_ROUNDS,
                            n_estimators=N_ESTIMATORS,
                            categorical_feature=CAT_FEATS)
    X_short.loc[type_train == t, 'oof'] = result_dict['oof']
    X_short_test.loc[type_test == t, 'prediction'] = result_dict['prediction']
    
    feature_importance = pd.concat([feature_importance, result_dict['feature_importance']], axis=0)
    
print('')
print('===== finish =====')
X['scalar_coupling_constant'] = y
X['type'] = type_train
metric = kaggle_metric(X, X_short['oof'])
X = X.drop(['scalar_coupling_constant', 'prediction', 'type'], axis=1)
print('CV mean score(group log mae): {0:.4f}'.format(metric))
prediction = X_short_test['prediction']
# Out:
# ********************************************************************************
# Training of type 1JHC
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:27:37 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 4.72014	valid_1's l1: 4.74692
# [200]	training's l1: 1.85688	valid_1's l1: 1.86946
# [300]	training's l1: 0.951704	valid_1's l1: 0.962432
# [400]	training's l1: 0.730365	valid_1's l1: 0.741204
# [500]	training's l1: 0.69038	valid_1's l1: 0.70122
# [600]	training's l1: 0.685045	valid_1's l1: 0.69599
# [700]	training's l1: 0.684502	valid_1's l1: 0.695613
# [800]	training's l1: 0.684425	valid_1's l1: 0.695674
# Early stopping, best iteration is:
# [693]	training's l1: 0.684509	valid_1's l1: 0.69561
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:28:07 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 4.72247	valid_1's l1: 4.73694
# [200]	training's l1: 1.86985	valid_1's l1: 1.87703
# [300]	training's l1: 0.964951	valid_1's l1: 0.96606
# [400]	training's l1: 0.743714	valid_1's l1: 0.740952
# [500]	training's l1: 0.703145	valid_1's l1: 0.698758
# [600]	training's l1: 0.697569	valid_1's l1: 0.692747
# [700]	training's l1: 0.696875	valid_1's l1: 0.692048
# [800]	training's l1: 0.696749	valid_1's l1: 0.691996
# [900]	training's l1: 0.696699	valid_1's l1: 0.691962
# [1000]	training's l1: 0.696656	valid_1's l1: 0.691957
# [1100]	training's l1: 0.696598	valid_1's l1: 0.691938
# [1200]	training's l1: 0.696544	valid_1's l1: 0.691917
# [1300]	training's l1: 0.696491	valid_1's l1: 0.691896
# [1400]	training's l1: 0.696442	valid_1's l1: 0.691872
# [1500]	training's l1: 0.696398	valid_1's l1: 0.691846
# Did not meet early stopping. Best iteration is:
# [1499]	training's l1: 0.696397	valid_1's l1: 0.691845
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:28:53 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 4.72601	valid_1's l1: 4.71667
# [200]	training's l1: 1.87718	valid_1's l1: 1.87403
# [300]	training's l1: 0.96966	valid_1's l1: 0.969025
# [400]	training's l1: 0.747408	valid_1's l1: 0.747309
# [500]	training's l1: 0.706321	valid_1's l1: 0.706657
# [600]	training's l1: 0.700366	valid_1's l1: 0.700986
# [700]	training's l1: 0.699603	valid_1's l1: 0.700364
# [800]	training's l1: 0.699429	valid_1's l1: 0.700354
# [900]	training's l1: 0.69934	valid_1's l1: 0.700386
# Early stopping, best iteration is:
# [738]	training's l1: 0.699519	valid_1's l1: 0.700345
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:29:24 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 4.73249	valid_1's l1: 4.70512
# [200]	training's l1: 1.88363	valid_1's l1: 1.86792
# [300]	training's l1: 0.975122	valid_1's l1: 0.964387
# [400]	training's l1: 0.752418	valid_1's l1: 0.745217
# [500]	training's l1: 0.711346	valid_1's l1: 0.705578
# [600]	training's l1: 0.705394	valid_1's l1: 0.700301
# [700]	training's l1: 0.70461	valid_1's l1: 0.699866
# [800]	training's l1: 0.704475	valid_1's l1: 0.699918
# Early stopping, best iteration is:
# [692]	training's l1: 0.70463	valid_1's l1: 0.699865
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:29:55 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 4.72857	valid_1's l1: 4.70948
# [200]	training's l1: 1.87878	valid_1's l1: 1.87369
# [300]	training's l1: 0.972766	valid_1's l1: 0.976029
# [400]	training's l1: 0.750962	valid_1's l1: 0.758559
# [500]	training's l1: 0.709929	valid_1's l1: 0.71916
# [600]	training's l1: 0.704014	valid_1's l1: 0.713679
# [700]	training's l1: 0.703254	valid_1's l1: 0.713138
# [800]	training's l1: 0.703091	valid_1's l1: 0.713115
# [900]	training's l1: 0.702985	valid_1's l1: 0.713083
# [1000]	training's l1: 0.702894	valid_1's l1: 0.713033
# [1100]	training's l1: 0.702814	valid_1's l1: 0.712994
# [1200]	training's l1: 0.702752	valid_1's l1: 0.712966
# [1300]	training's l1: 0.702717	valid_1's l1: 0.712947
# [1400]	training's l1: 0.702676	valid_1's l1: 0.712927
# [1500]	training's l1: 0.702635	valid_1's l1: 0.71291
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.702635	valid_1's l1: 0.71291
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:30:40 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 4.72086	valid_1's l1: 4.73882
# [200]	training's l1: 1.86771	valid_1's l1: 1.87479
# [300]	training's l1: 0.962977	valid_1's l1: 0.966776
# [400]	training's l1: 0.741551	valid_1's l1: 0.745075
# [500]	training's l1: 0.700839	valid_1's l1: 0.705037
# [600]	training's l1: 0.695138	valid_1's l1: 0.699853
# [700]	training's l1: 0.694419	valid_1's l1: 0.699366
# [800]	training's l1: 0.694274	valid_1's l1: 0.699383
# [900]	training's l1: 0.694211	valid_1's l1: 0.699411
# Early stopping, best iteration is:
# [719]	training's l1: 0.694377	valid_1's l1: 0.699356
# ------------------
# ====== finish ======
# score list: [0.6956096244206441, 0.6918450371762297, 0.7003452345964363, 0.6998647423668487, 0.7129104306955322, 0.6993563111949884]
# CV mean score(group log mae): -0.3567
#
# ********************************************************************************
# Training of type 1JHN
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:31:13 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 3.57535	valid_1's l1: 3.60186
# [200]	training's l1: 1.34434	valid_1's l1: 1.3605
# [300]	training's l1: 0.585099	valid_1's l1: 0.594696
# [400]	training's l1: 0.38392	valid_1's l1: 0.390577
# [500]	training's l1: 0.346161	valid_1's l1: 0.353622
# [600]	training's l1: 0.339888	valid_1's l1: 0.348934
# [700]	training's l1: 0.338308	valid_1's l1: 0.348801
# [800]	training's l1: 0.337628	valid_1's l1: 0.349187
# Early stopping, best iteration is:
# [655]	training's l1: 0.338811	valid_1's l1: 0.348669
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:31:16 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 3.58266	valid_1's l1: 3.56705
# [200]	training's l1: 1.34757	valid_1's l1: 1.34683
# [300]	training's l1: 0.585603	valid_1's l1: 0.592322
# [400]	training's l1: 0.38267	valid_1's l1: 0.391607
# [500]	training's l1: 0.344694	valid_1's l1: 0.354485
# [600]	training's l1: 0.338537	valid_1's l1: 0.349226
# [700]	training's l1: 0.337016	valid_1's l1: 0.348756
# [800]	training's l1: 0.336384	valid_1's l1: 0.349058
# Early stopping, best iteration is:
# [698]	training's l1: 0.337035	valid_1's l1: 0.348753
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:31:19 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 3.57466	valid_1's l1: 3.59332
# [200]	training's l1: 1.34484	valid_1's l1: 1.34596
# [300]	training's l1: 0.585033	valid_1's l1: 0.583991
# [400]	training's l1: 0.382398	valid_1's l1: 0.389093
# [500]	training's l1: 0.344482	valid_1's l1: 0.355036
# [600]	training's l1: 0.338516	valid_1's l1: 0.350848
# [700]	training's l1: 0.337046	valid_1's l1: 0.350732
# [800]	training's l1: 0.336374	valid_1's l1: 0.351138
# Early stopping, best iteration is:
# [650]	training's l1: 0.337604	valid_1's l1: 0.350644
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:31:22 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 3.57739	valid_1's l1: 3.5741
# [200]	training's l1: 1.34564	valid_1's l1: 1.33581
# [300]	training's l1: 0.586106	valid_1's l1: 0.576931
# [400]	training's l1: 0.384786	valid_1's l1: 0.380271
# [500]	training's l1: 0.347296	valid_1's l1: 0.345846
# [600]	training's l1: 0.341098	valid_1's l1: 0.341815
# [700]	training's l1: 0.339658	valid_1's l1: 0.341848
# [800]	training's l1: 0.33896	valid_1's l1: 0.342176
# Early stopping, best iteration is:
# [636]	training's l1: 0.340386	valid_1's l1: 0.341698
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:31:24 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 3.58786	valid_1's l1: 3.53556
# [200]	training's l1: 1.3485	valid_1's l1: 1.33819
# [300]	training's l1: 0.585442	valid_1's l1: 0.589926
# [400]	training's l1: 0.382575	valid_1's l1: 0.392402
# [500]	training's l1: 0.344888	valid_1's l1: 0.35619
# [600]	training's l1: 0.338785	valid_1's l1: 0.351621
# [700]	training's l1: 0.337302	valid_1's l1: 0.35138
# [800]	training's l1: 0.336663	valid_1's l1: 0.351505
# Early stopping, best iteration is:
# [671]	training's l1: 0.337594	valid_1's l1: 0.351352
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:31:27 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 3.5742	valid_1's l1: 3.60394
# [200]	training's l1: 1.34427	valid_1's l1: 1.3573
# [300]	training's l1: 0.583817	valid_1's l1: 0.597475
# [400]	training's l1: 0.381337	valid_1's l1: 0.398221
# [500]	training's l1: 0.343202	valid_1's l1: 0.363047
# [600]	training's l1: 0.336938	valid_1's l1: 0.358935
# [700]	training's l1: 0.335442	valid_1's l1: 0.358865
# [800]	training's l1: 0.334739	valid_1's l1: 0.359186
# Early stopping, best iteration is:
# [678]	training's l1: 0.335663	valid_1's l1: 0.35877
# ------------------
# ====== finish ======
# score list: [0.3486693111741911, 0.3487527862582116, 0.3506444958220585, 0.3416983987476114, 0.3513519270041342, 0.3587701251243666]
# CV mean score(group log mae): -1.0499
#
# ********************************************************************************
# Training of type 2JHC
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:31:31 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.02982	valid_1's l1: 1.02999
# [200]	training's l1: 0.450448	valid_1's l1: 0.452182
# [300]	training's l1: 0.283811	valid_1's l1: 0.285966
# [400]	training's l1: 0.249613	valid_1's l1: 0.251599
# [500]	training's l1: 0.244548	valid_1's l1: 0.246476
# [600]	training's l1: 0.243949	valid_1's l1: 0.245907
# [700]	training's l1: 0.243871	valid_1's l1: 0.245889
# [800]	training's l1: 0.243822	valid_1's l1: 0.245903
# Early stopping, best iteration is:
# [671]	training's l1: 0.243885	valid_1's l1: 0.245885
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:32:20 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.0307	valid_1's l1: 1.02382
# [200]	training's l1: 0.45109	valid_1's l1: 0.447463
# [300]	training's l1: 0.285095	valid_1's l1: 0.283032
# [400]	training's l1: 0.250987	valid_1's l1: 0.250044
# [500]	training's l1: 0.245777	valid_1's l1: 0.245284
# [600]	training's l1: 0.245104	valid_1's l1: 0.244799
# [700]	training's l1: 0.244994	valid_1's l1: 0.244791
# [800]	training's l1: 0.244931	valid_1's l1: 0.244808
# Early stopping, best iteration is:
# [669]	training's l1: 0.245014	valid_1's l1: 0.244787
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:33:10 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.02855	valid_1's l1: 1.03559
# [200]	training's l1: 0.45007	valid_1's l1: 0.454164
# [300]	training's l1: 0.284067	valid_1's l1: 0.287033
# [400]	training's l1: 0.250118	valid_1's l1: 0.252138
# [500]	training's l1: 0.244957	valid_1's l1: 0.24683
# [600]	training's l1: 0.24433	valid_1's l1: 0.246257
# [700]	training's l1: 0.244237	valid_1's l1: 0.246238
# [800]	training's l1: 0.244182	valid_1's l1: 0.24625
# Early stopping, best iteration is:
# [650]	training's l1: 0.244272	valid_1's l1: 0.246234
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:33:58 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.03042	valid_1's l1: 1.02565
# [200]	training's l1: 0.450706	valid_1's l1: 0.448534
# [300]	training's l1: 0.283853	valid_1's l1: 0.283245
# [400]	training's l1: 0.249724	valid_1's l1: 0.249918
# [500]	training's l1: 0.244788	valid_1's l1: 0.245311
# [600]	training's l1: 0.244232	valid_1's l1: 0.244937
# [700]	training's l1: 0.244162	valid_1's l1: 0.24498
# [800]	training's l1: 0.244108	valid_1's l1: 0.24502
# Early stopping, best iteration is:
# [601]	training's l1: 0.244231	valid_1's l1: 0.244937
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:34:41 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.02944	valid_1's l1: 1.03092
# [200]	training's l1: 0.450427	valid_1's l1: 0.451075
# [300]	training's l1: 0.283623	valid_1's l1: 0.28411
# [400]	training's l1: 0.249759	valid_1's l1: 0.250396
# [500]	training's l1: 0.244887	valid_1's l1: 0.245626
# [600]	training's l1: 0.244331	valid_1's l1: 0.245147
# [700]	training's l1: 0.244259	valid_1's l1: 0.245152
# [800]	training's l1: 0.244216	valid_1's l1: 0.245186
# Early stopping, best iteration is:
# [635]	training's l1: 0.244295	valid_1's l1: 0.245134
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:35:26 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.0288	valid_1's l1: 1.03155
# [200]	training's l1: 0.450366	valid_1's l1: 0.450432
# [300]	training's l1: 0.284572	valid_1's l1: 0.284464
# [400]	training's l1: 0.250594	valid_1's l1: 0.250872
# [500]	training's l1: 0.245413	valid_1's l1: 0.245896
# [600]	training's l1: 0.244784	valid_1's l1: 0.245401
# [700]	training's l1: 0.244681	valid_1's l1: 0.245404
# [800]	training's l1: 0.244625	valid_1's l1: 0.24542
# Early stopping, best iteration is:
# [621]	training's l1: 0.244748	valid_1's l1: 0.245393
# ------------------
# ====== finish ======
# score list: [0.2458850334369569, 0.24478691903517225, 0.24623368691075312, 0.24493672226299604, 0.24513406426052184, 0.24539298093967346]
# CV mean score(group log mae): -1.4049
#
# ********************************************************************************
# Training of type 2JHH
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:36:11 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.992564	valid_1's l1: 0.993381
# [200]	training's l1: 0.397485	valid_1's l1: 0.397561
# [300]	training's l1: 0.209758	valid_1's l1: 0.210062
# [400]	training's l1: 0.16401	valid_1's l1: 0.164906
# [500]	training's l1: 0.155888	valid_1's l1: 0.157227
# [600]	training's l1: 0.154573	valid_1's l1: 0.156284
# [700]	training's l1: 0.154283	valid_1's l1: 0.156242
# [800]	training's l1: 0.154145	valid_1's l1: 0.156284
# Early stopping, best iteration is:
# [644]	training's l1: 0.154405	valid_1's l1: 0.156228
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:36:36 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.992963	valid_1's l1: 0.994842
# [200]	training's l1: 0.397402	valid_1's l1: 0.399614
# [300]	training's l1: 0.209463	valid_1's l1: 0.212485
# [400]	training's l1: 0.16359	valid_1's l1: 0.167717
# [500]	training's l1: 0.15546	valid_1's l1: 0.159999
# [600]	training's l1: 0.154149	valid_1's l1: 0.158968
# [700]	training's l1: 0.153858	valid_1's l1: 0.158852
# [800]	training's l1: 0.153734	valid_1's l1: 0.158892
# [900]	training's l1: 0.153654	valid_1's l1: 0.158925
# Early stopping, best iteration is:
# [711]	training's l1: 0.153839	valid_1's l1: 0.158849
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:37:04 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.994035	valid_1's l1: 0.992893
# [200]	training's l1: 0.397835	valid_1's l1: 0.39867
# [300]	training's l1: 0.20964	valid_1's l1: 0.211656
# [400]	training's l1: 0.163655	valid_1's l1: 0.166673
# [500]	training's l1: 0.155489	valid_1's l1: 0.159027
# [600]	training's l1: 0.154171	valid_1's l1: 0.158077
# [700]	training's l1: 0.153875	valid_1's l1: 0.157998
# [800]	training's l1: 0.153737	valid_1's l1: 0.158037
# Early stopping, best iteration is:
# [659]	training's l1: 0.153956	valid_1's l1: 0.157989
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:37:30 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.994867	valid_1's l1: 0.986393
# [200]	training's l1: 0.398233	valid_1's l1: 0.395454
# [300]	training's l1: 0.209892	valid_1's l1: 0.20982
# [400]	training's l1: 0.16392	valid_1's l1: 0.164936
# [500]	training's l1: 0.155731	valid_1's l1: 0.157297
# [600]	training's l1: 0.154417	valid_1's l1: 0.156382
# [700]	training's l1: 0.154112	valid_1's l1: 0.156331
# [800]	training's l1: 0.153983	valid_1's l1: 0.15638
# Early stopping, best iteration is:
# [651]	training's l1: 0.154217	valid_1's l1: 0.156326
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:37:56 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.992948	valid_1's l1: 0.995165
# [200]	training's l1: 0.397631	valid_1's l1: 0.399647
# [300]	training's l1: 0.209765	valid_1's l1: 0.211772
# [400]	training's l1: 0.163986	valid_1's l1: 0.165647
# [500]	training's l1: 0.155864	valid_1's l1: 0.157678
# [600]	training's l1: 0.154553	valid_1's l1: 0.15663
# [700]	training's l1: 0.154238	valid_1's l1: 0.156538
# [800]	training's l1: 0.154114	valid_1's l1: 0.156585
# Early stopping, best iteration is:
# [690]	training's l1: 0.154258	valid_1's l1: 0.156535
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:38:24 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.991641	valid_1's l1: 0.998192
# [200]	training's l1: 0.397054	valid_1's l1: 0.400032
# [300]	training's l1: 0.20948	valid_1's l1: 0.211877
# [400]	training's l1: 0.163834	valid_1's l1: 0.166373
# [500]	training's l1: 0.155756	valid_1's l1: 0.1587
# [600]	training's l1: 0.15444	valid_1's l1: 0.157702
# [700]	training's l1: 0.154117	valid_1's l1: 0.157614
# [800]	training's l1: 0.153981	valid_1's l1: 0.157664
# Early stopping, best iteration is:
# [684]	training's l1: 0.154146	valid_1's l1: 0.157611
# ------------------
# ====== finish ======
# score list: [0.15622785501860315, 0.15884944306577722, 0.1579890410401116, 0.15632630247698961, 0.1565353236681642, 0.15761113389779993]
# CV mean score(group log mae): -1.8499
#
# ********************************************************************************
# Training of type 2JHN
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:38:51 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.09876	valid_1's l1: 1.10675
# [200]	training's l1: 0.434973	valid_1's l1: 0.439171
# [300]	training's l1: 0.215767	valid_1's l1: 0.219295
# [400]	training's l1: 0.156661	valid_1's l1: 0.160038
# [500]	training's l1: 0.144816	valid_1's l1: 0.148577
# [600]	training's l1: 0.142724	valid_1's l1: 0.146773
# [700]	training's l1: 0.142146	valid_1's l1: 0.146473
# [800]	training's l1: 0.14185	valid_1's l1: 0.146454
# [900]	training's l1: 0.141654	valid_1's l1: 0.146468
# [1000]	training's l1: 0.141521	valid_1's l1: 0.146456
# Early stopping, best iteration is:
# [808]	training's l1: 0.141832	valid_1's l1: 0.146452
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:38:58 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.09871	valid_1's l1: 1.10368
# [200]	training's l1: 0.434765	valid_1's l1: 0.436934
# [300]	training's l1: 0.215561	valid_1's l1: 0.217824
# [400]	training's l1: 0.156598	valid_1's l1: 0.159196
# [500]	training's l1: 0.14484	valid_1's l1: 0.147927
# [600]	training's l1: 0.142748	valid_1's l1: 0.14633
# [700]	training's l1: 0.142164	valid_1's l1: 0.14613
# [800]	training's l1: 0.141885	valid_1's l1: 0.146143
# [900]	training's l1: 0.14168	valid_1's l1: 0.146176
# Early stopping, best iteration is:
# [725]	training's l1: 0.142076	valid_1's l1: 0.146116
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:39:04 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.09916	valid_1's l1: 1.10503
# [200]	training's l1: 0.435016	valid_1's l1: 0.438601
# [300]	training's l1: 0.215781	valid_1's l1: 0.218691
# [400]	training's l1: 0.156629	valid_1's l1: 0.159843
# [500]	training's l1: 0.144803	valid_1's l1: 0.148195
# [600]	training's l1: 0.142708	valid_1's l1: 0.146381
# [700]	training's l1: 0.142148	valid_1's l1: 0.146077
# [800]	training's l1: 0.141846	valid_1's l1: 0.146036
# [900]	training's l1: 0.141635	valid_1's l1: 0.146059
# Early stopping, best iteration is:
# [795]	training's l1: 0.141855	valid_1's l1: 0.146035
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:39:10 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.10244	valid_1's l1: 1.09421
# [200]	training's l1: 0.436378	valid_1's l1: 0.434904
# [300]	training's l1: 0.216259	valid_1's l1: 0.21718
# [400]	training's l1: 0.156737	valid_1's l1: 0.158939
# [500]	training's l1: 0.144888	valid_1's l1: 0.147806
# [600]	training's l1: 0.142791	valid_1's l1: 0.146146
# [700]	training's l1: 0.142194	valid_1's l1: 0.145947
# [800]	training's l1: 0.141905	valid_1's l1: 0.145942
# [900]	training's l1: 0.141695	valid_1's l1: 0.145973
# Early stopping, best iteration is:
# [744]	training's l1: 0.142046	valid_1's l1: 0.145932
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:39:17 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.10059	valid_1's l1: 1.09341
# [200]	training's l1: 0.435357	valid_1's l1: 0.432733
# [300]	training's l1: 0.2157	valid_1's l1: 0.216277
# [400]	training's l1: 0.156514	valid_1's l1: 0.159052
# [500]	training's l1: 0.144628	valid_1's l1: 0.148274
# [600]	training's l1: 0.142557	valid_1's l1: 0.146757
# [700]	training's l1: 0.142	valid_1's l1: 0.146577
# [800]	training's l1: 0.141693	valid_1's l1: 0.146561
# [900]	training's l1: 0.141469	valid_1's l1: 0.146582
# Early stopping, best iteration is:
# [734]	training's l1: 0.141877	valid_1's l1: 0.146556
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:39:24 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.10122	valid_1's l1: 1.09904
# [200]	training's l1: 0.436067	valid_1's l1: 0.434341
# [300]	training's l1: 0.216533	valid_1's l1: 0.214663
# [400]	training's l1: 0.157413	valid_1's l1: 0.155665
# [500]	training's l1: 0.145636	valid_1's l1: 0.144268
# [600]	training's l1: 0.14356	valid_1's l1: 0.142658
# [700]	training's l1: 0.142977	valid_1's l1: 0.142515
# [800]	training's l1: 0.142676	valid_1's l1: 0.142524
# [900]	training's l1: 0.142444	valid_1's l1: 0.142555
# Early stopping, best iteration is:
# [724]	training's l1: 0.142893	valid_1's l1: 0.142507
# ------------------
# ====== finish ======
# score list: [0.14645150269217488, 0.14611587270591164, 0.14603463999244948, 0.1459317545701325, 0.14655585949645408, 0.14250741206032322]
# CV mean score(group log mae): -1.9269
#
# ********************************************************************************
# Training of type 3JHC
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:39:31 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.943171	valid_1's l1: 0.943746
# [200]	training's l1: 0.419873	valid_1's l1: 0.420493
# [300]	training's l1: 0.276829	valid_1's l1: 0.277572
# [400]	training's l1: 0.248452	valid_1's l1: 0.24947
# [500]	training's l1: 0.244035	valid_1's l1: 0.245226
# [600]	training's l1: 0.243364	valid_1's l1: 0.244681
# [700]	training's l1: 0.243217	valid_1's l1: 0.244613
# [800]	training's l1: 0.243131	valid_1's l1: 0.244598
# [900]	training's l1: 0.243054	valid_1's l1: 0.244583
# [1000]	training's l1: 0.242996	valid_1's l1: 0.24457
# [1100]	training's l1: 0.242945	valid_1's l1: 0.244559
# [1200]	training's l1: 0.242897	valid_1's l1: 0.244554
# [1300]	training's l1: 0.242851	valid_1's l1: 0.244549
# [1400]	training's l1: 0.242802	valid_1's l1: 0.244541
# [1500]	training's l1: 0.242747	valid_1's l1: 0.244535
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.242747	valid_1's l1: 0.244535
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:41:13 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.942174	valid_1's l1: 0.948205
# [200]	training's l1: 0.419416	valid_1's l1: 0.422572
# [300]	training's l1: 0.276529	valid_1's l1: 0.279227
# [400]	training's l1: 0.2482	valid_1's l1: 0.251087
# [500]	training's l1: 0.243813	valid_1's l1: 0.246819
# [600]	training's l1: 0.243147	valid_1's l1: 0.246238
# [700]	training's l1: 0.24298	valid_1's l1: 0.246167
# [800]	training's l1: 0.242891	valid_1's l1: 0.246165
# [900]	training's l1: 0.242826	valid_1's l1: 0.246167
# Early stopping, best iteration is:
# [752]	training's l1: 0.242929	valid_1's l1: 0.246161
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:42:27 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.943321	valid_1's l1: 0.94131
# [200]	training's l1: 0.419946	valid_1's l1: 0.418945
# [300]	training's l1: 0.276931	valid_1's l1: 0.276264
# [400]	training's l1: 0.248619	valid_1's l1: 0.248109
# [500]	training's l1: 0.24424	valid_1's l1: 0.243845
# [600]	training's l1: 0.243556	valid_1's l1: 0.243269
# [700]	training's l1: 0.243394	valid_1's l1: 0.243193
# [800]	training's l1: 0.243302	valid_1's l1: 0.243172
# [900]	training's l1: 0.243221	valid_1's l1: 0.243162
# [1000]	training's l1: 0.243157	valid_1's l1: 0.24316
# [1100]	training's l1: 0.243104	valid_1's l1: 0.243162
# Early stopping, best iteration is:
# [988]	training's l1: 0.243164	valid_1's l1: 0.243159
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:43:49 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.94357	valid_1's l1: 0.940122
# [200]	training's l1: 0.420129	valid_1's l1: 0.417916
# [300]	training's l1: 0.27713	valid_1's l1: 0.275417
# [400]	training's l1: 0.248832	valid_1's l1: 0.247486
# [500]	training's l1: 0.244463	valid_1's l1: 0.243344
# [600]	training's l1: 0.243808	valid_1's l1: 0.242809
# [700]	training's l1: 0.243657	valid_1's l1: 0.242736
# [800]	training's l1: 0.24357	valid_1's l1: 0.242723
# [900]	training's l1: 0.243498	valid_1's l1: 0.242714
# [1000]	training's l1: 0.243436	valid_1's l1: 0.242701
# [1100]	training's l1: 0.243385	valid_1's l1: 0.242692
# [1200]	training's l1: 0.243334	valid_1's l1: 0.242686
# [1300]	training's l1: 0.243286	valid_1's l1: 0.242683
# [1400]	training's l1: 0.243238	valid_1's l1: 0.242677
# [1500]	training's l1: 0.24319	valid_1's l1: 0.242672
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.24319	valid_1's l1: 0.242672
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:45:35 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.943208	valid_1's l1: 0.942141
# [200]	training's l1: 0.419862	valid_1's l1: 0.419344
# [300]	training's l1: 0.276834	valid_1's l1: 0.276671
# [400]	training's l1: 0.248564	valid_1's l1: 0.248431
# [500]	training's l1: 0.244187	valid_1's l1: 0.244098
# [600]	training's l1: 0.24353	valid_1's l1: 0.243513
# [700]	training's l1: 0.243373	valid_1's l1: 0.243424
# [800]	training's l1: 0.243289	valid_1's l1: 0.243405
# [900]	training's l1: 0.243212	valid_1's l1: 0.24339
# [1000]	training's l1: 0.243149	valid_1's l1: 0.243374
# [1100]	training's l1: 0.243099	valid_1's l1: 0.243363
# [1200]	training's l1: 0.243052	valid_1's l1: 0.243354
# [1300]	training's l1: 0.243008	valid_1's l1: 0.243345
# [1400]	training's l1: 0.242968	valid_1's l1: 0.243343
# [1500]	training's l1: 0.242921	valid_1's l1: 0.243334
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.242921	valid_1's l1: 0.243334
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:47:17 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.943126	valid_1's l1: 0.943097
# [200]	training's l1: 0.419773	valid_1's l1: 0.420458
# [300]	training's l1: 0.276781	valid_1's l1: 0.277626
# [400]	training's l1: 0.24847	valid_1's l1: 0.249264
# [500]	training's l1: 0.244081	valid_1's l1: 0.244915
# [600]	training's l1: 0.24342	valid_1's l1: 0.244319
# [700]	training's l1: 0.243266	valid_1's l1: 0.244239
# [800]	training's l1: 0.243181	valid_1's l1: 0.244223
# [900]	training's l1: 0.243105	valid_1's l1: 0.244216
# [1000]	training's l1: 0.24304	valid_1's l1: 0.244213
# [1100]	training's l1: 0.242982	valid_1's l1: 0.244205
# [1200]	training's l1: 0.242927	valid_1's l1: 0.244203
# [1300]	training's l1: 0.242873	valid_1's l1: 0.2442
# [1400]	training's l1: 0.242824	valid_1's l1: 0.244201
# [1500]	training's l1: 0.242779	valid_1's l1: 0.244203
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.242779	valid_1's l1: 0.244203
# ------------------
# ====== finish ======
# score list: [0.24453451414604255, 0.24616105384617673, 0.24315935301635042, 0.24267245720785813, 0.24333392728680714, 0.24420261181288164]
# CV mean score(group log mae): -1.4105
#
# ********************************************************************************
# Training of type 3JHH
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:49:05 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.14023	valid_1's l1: 1.14057
# [200]	training's l1: 0.450589	valid_1's l1: 0.450188
# [300]	training's l1: 0.223251	valid_1's l1: 0.223128
# [400]	training's l1: 0.160486	valid_1's l1: 0.161016
# [500]	training's l1: 0.14687	valid_1's l1: 0.147861
# [600]	training's l1: 0.144406	valid_1's l1: 0.145643
# [700]	training's l1: 0.143869	valid_1's l1: 0.145294
# [800]	training's l1: 0.143649	valid_1's l1: 0.145242
# [900]	training's l1: 0.14353	valid_1's l1: 0.145239
# [1000]	training's l1: 0.143421	valid_1's l1: 0.145226
# [1100]	training's l1: 0.143346	valid_1's l1: 0.145217
# [1200]	training's l1: 0.143289	valid_1's l1: 0.145211
# [1300]	training's l1: 0.143236	valid_1's l1: 0.145207
# [1400]	training's l1: 0.143183	valid_1's l1: 0.145203
# [1500]	training's l1: 0.143147	valid_1's l1: 0.145199
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.143147	valid_1's l1: 0.145199
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:50:03 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.14034	valid_1's l1: 1.13872
# [200]	training's l1: 0.450545	valid_1's l1: 0.449993
# [300]	training's l1: 0.223151	valid_1's l1: 0.223562
# [400]	training's l1: 0.160388	valid_1's l1: 0.16129
# [500]	training's l1: 0.146797	valid_1's l1: 0.148005
# [600]	training's l1: 0.144311	valid_1's l1: 0.145749
# [700]	training's l1: 0.143758	valid_1's l1: 0.145401
# [800]	training's l1: 0.143529	valid_1's l1: 0.14535
# [900]	training's l1: 0.143406	valid_1's l1: 0.145348
# [1000]	training's l1: 0.143297	valid_1's l1: 0.145348
# [1100]	training's l1: 0.143219	valid_1's l1: 0.145339
# [1200]	training's l1: 0.143158	valid_1's l1: 0.145333
# [1300]	training's l1: 0.143107	valid_1's l1: 0.145332
# [1400]	training's l1: 0.143073	valid_1's l1: 0.145327
# [1500]	training's l1: 0.143039	valid_1's l1: 0.14532
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.143039	valid_1's l1: 0.14532
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:51:00 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.13976	valid_1's l1: 1.14112
# [200]	training's l1: 0.450294	valid_1's l1: 0.450937
# [300]	training's l1: 0.223063	valid_1's l1: 0.223742
# [400]	training's l1: 0.160304	valid_1's l1: 0.161552
# [500]	training's l1: 0.146672	valid_1's l1: 0.148441
# [600]	training's l1: 0.144197	valid_1's l1: 0.146292
# [700]	training's l1: 0.143659	valid_1's l1: 0.145997
# [800]	training's l1: 0.14344	valid_1's l1: 0.145952
# [900]	training's l1: 0.143314	valid_1's l1: 0.145956
# [1000]	training's l1: 0.143203	valid_1's l1: 0.145953
# [1100]	training's l1: 0.143128	valid_1's l1: 0.145943
# [1200]	training's l1: 0.14307	valid_1's l1: 0.145936
# [1300]	training's l1: 0.14302	valid_1's l1: 0.14593
# [1400]	training's l1: 0.142977	valid_1's l1: 0.145926
# [1500]	training's l1: 0.142938	valid_1's l1: 0.14592
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.142938	valid_1's l1: 0.14592
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:51:56 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.13963	valid_1's l1: 1.14326
# [200]	training's l1: 0.450178	valid_1's l1: 0.452304
# [300]	training's l1: 0.222926	valid_1's l1: 0.224869
# [400]	training's l1: 0.160229	valid_1's l1: 0.162326
# [500]	training's l1: 0.146638	valid_1's l1: 0.148849
# [600]	training's l1: 0.144179	valid_1's l1: 0.146554
# [700]	training's l1: 0.143638	valid_1's l1: 0.146188
# [800]	training's l1: 0.143417	valid_1's l1: 0.146127
# [900]	training's l1: 0.143294	valid_1's l1: 0.146125
# [1000]	training's l1: 0.143183	valid_1's l1: 0.146128
# Early stopping, best iteration is:
# [851]	training's l1: 0.143347	valid_1's l1: 0.146123
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:52:32 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.13983	valid_1's l1: 1.14152
# [200]	training's l1: 0.45021	valid_1's l1: 0.451772
# [300]	training's l1: 0.222965	valid_1's l1: 0.22456
# [400]	training's l1: 0.160333	valid_1's l1: 0.161843
# [500]	training's l1: 0.146766	valid_1's l1: 0.148413
# [600]	training's l1: 0.144287	valid_1's l1: 0.146159
# [700]	training's l1: 0.143739	valid_1's l1: 0.145817
# [800]	training's l1: 0.143516	valid_1's l1: 0.145762
# [900]	training's l1: 0.143388	valid_1's l1: 0.145756
# [1000]	training's l1: 0.14328	valid_1's l1: 0.145745
# [1100]	training's l1: 0.143194	valid_1's l1: 0.145738
# [1200]	training's l1: 0.143137	valid_1's l1: 0.145733
# [1300]	training's l1: 0.143073	valid_1's l1: 0.145731
# [1400]	training's l1: 0.143009	valid_1's l1: 0.14573
# [1500]	training's l1: 0.14294	valid_1's l1: 0.145729
# Did not meet early stopping. Best iteration is:
# [1500]	training's l1: 0.14294	valid_1's l1: 0.145729
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:53:31 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 1.14092	valid_1's l1: 1.13655
# [200]	training's l1: 0.450538	valid_1's l1: 0.450018
# [300]	training's l1: 0.223068	valid_1's l1: 0.223738
# [400]	training's l1: 0.160312	valid_1's l1: 0.161471
# [500]	training's l1: 0.146732	valid_1's l1: 0.148273
# [600]	training's l1: 0.144275	valid_1's l1: 0.146136
# [700]	training's l1: 0.143733	valid_1's l1: 0.145822
# [800]	training's l1: 0.143508	valid_1's l1: 0.145776
# [900]	training's l1: 0.143386	valid_1's l1: 0.145782
# Early stopping, best iteration is:
# [798]	training's l1: 0.143511	valid_1's l1: 0.145775
# ------------------
# ====== finish ======
# score list: [0.14519851477539852, 0.14532046730800116, 0.1459195117619639, 0.1461234667194786, 0.1457285656339608, 0.14577492805664646]
# CV mean score(group log mae): -1.9264
#
# ********************************************************************************
# Training of type 3JHN
# ********************************************************************************
# ------------------
# - fold1
# Fold 1 started at Sun Aug 25 22:54:05 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.373668	valid_1's l1: 0.373786
# [200]	training's l1: 0.175141	valid_1's l1: 0.175006
# [300]	training's l1: 0.120731	valid_1's l1: 0.121783
# [400]	training's l1: 0.109692	valid_1's l1: 0.112045
# [500]	training's l1: 0.107679	valid_1's l1: 0.110948
# [600]	training's l1: 0.107125	valid_1's l1: 0.110966
# [700]	training's l1: 0.106861	valid_1's l1: 0.111075
# Early stopping, best iteration is:
# [543]	training's l1: 0.107373	valid_1's l1: 0.110923
# ------------------
# - fold2
# Fold 2 started at Sun Aug 25 22:54:15 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.373646	valid_1's l1: 0.375521
# [200]	training's l1: 0.174824	valid_1's l1: 0.178682
# [300]	training's l1: 0.120335	valid_1's l1: 0.125139
# [400]	training's l1: 0.109375	valid_1's l1: 0.114496
# [500]	training's l1: 0.107353	valid_1's l1: 0.112926
# [600]	training's l1: 0.106806	valid_1's l1: 0.112736
# [700]	training's l1: 0.106563	valid_1's l1: 0.112794
# [800]	training's l1: 0.106413	valid_1's l1: 0.112849
# Early stopping, best iteration is:
# [600]	training's l1: 0.106806	valid_1's l1: 0.112736
# ------------------
# - fold3
# Fold 3 started at Sun Aug 25 22:54:25 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.373161	valid_1's l1: 0.375449
# [200]	training's l1: 0.174754	valid_1's l1: 0.17762
# [300]	training's l1: 0.120436	valid_1's l1: 0.124315
# [400]	training's l1: 0.109407	valid_1's l1: 0.114194
# [500]	training's l1: 0.107361	valid_1's l1: 0.112868
# [600]	training's l1: 0.106787	valid_1's l1: 0.112776
# [700]	training's l1: 0.106523	valid_1's l1: 0.112824
# Early stopping, best iteration is:
# [566]	training's l1: 0.106928	valid_1's l1: 0.112764
# ------------------
# - fold4
# Fold 4 started at Sun Aug 25 22:54:35 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.37457	valid_1's l1: 0.370025
# [200]	training's l1: 0.17534	valid_1's l1: 0.174358
# [300]	training's l1: 0.120799	valid_1's l1: 0.121838
# [400]	training's l1: 0.109819	valid_1's l1: 0.111974
# [500]	training's l1: 0.107823	valid_1's l1: 0.110643
# [600]	training's l1: 0.107284	valid_1's l1: 0.110559
# [700]	training's l1: 0.107034	valid_1's l1: 0.110629
# Early stopping, best iteration is:
# [576]	training's l1: 0.107365	valid_1's l1: 0.110551
# ------------------
# - fold5
# Fold 5 started at Sun Aug 25 22:54:45 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.373799	valid_1's l1: 0.374695
# [200]	training's l1: 0.175098	valid_1's l1: 0.177272
# [300]	training's l1: 0.120651	valid_1's l1: 0.123508
# [400]	training's l1: 0.109582	valid_1's l1: 0.113156
# [500]	training's l1: 0.10757	valid_1's l1: 0.1117
# [600]	training's l1: 0.107033	valid_1's l1: 0.111581
# [700]	training's l1: 0.10678	valid_1's l1: 0.111621
# Early stopping, best iteration is:
# [584]	training's l1: 0.107083	valid_1's l1: 0.111577
# ------------------
# - fold6
# Fold 6 started at Sun Aug 25 22:54:55 2019
# Training until validation scores don't improve for 200 rounds.
# [100]	training's l1: 0.373509	valid_1's l1: 0.376569
# [200]	training's l1: 0.175148	valid_1's l1: 0.177018
# [300]	training's l1: 0.120845	valid_1's l1: 0.122763
# [400]	training's l1: 0.109854	valid_1's l1: 0.112177
# [500]	training's l1: 0.107832	valid_1's l1: 0.110626
# [600]	training's l1: 0.107291	valid_1's l1: 0.110469
# [700]	training's l1: 0.10702	valid_1's l1: 0.110519
# Early stopping, best iteration is:
# [596]	training's l1: 0.107305	valid_1's l1: 0.110468
# ------------------
# ====== finish ======
# score list: [0.11092317509353994, 0.1127358219635634, 0.11276423341230096, 0.11055098215450897, 0.1115772916641915, 0.11046834022817846]
# CV mean score(group log mae): -2.1937
#
#
# ===== finish =====
# CV mean score(group log mae): -1.5149
# CPU times: user 2h 13min 31s, sys: 22 s, total: 2h 13min 53s
# Wall time: 27min 47s

# %% [markdown]
# ## plot feature importance

# %%
# top 50 features
cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
    by="importance", ascending=False)[:50].index

best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
plt.title('LGB Features (avg over folds)');

# %% [markdown]
# # Save

# %% [markdown]
# **submission**

# %%
# path_submittion = './output/' + 'nb{}_submission_lgb_{}.csv'.format(nb, metric)
path_submittion = '../output/nb{}_stack_submission_lgb_{}.csv'.format(nb, metric)
print(f'save pash: {path_submittion}')
# Out:
# save pash: ../output/nb76_stack_submission_lgb_-1.5148537542130542.csv

# %%
submittion = pd.read_csv('../input/champs-scalar-coupling/sample_submission.csv')
# submittion = pd.read_csv('./input/champs-scalar-coupling/sample_submission.csv')[::100]
if isSmallSet:
    pass
else:
    submittion['scalar_coupling_constant'] = prediction
    submittion.to_csv(path_submittion, index=False)

# %% [markdown]
# ---
# **result**

# %%
path_oof = '../output/' + 'nb{}_stack_oof_lgb_{}.csv'.format(nb, metric)
print(f'save pash: {path_oof}')
# Out:
# save pash: ../output/nb76_stack_oof_lgb_-1.5148537542130542.csv

# %%
oof = pd.DataFrame(X_short['oof'])
if isSmallSet:
    pass
else:
    oof.to_csv(path_oof, index=False)

# %% [markdown]
# # analysis

# %%
plot_data = pd.DataFrame(y)
plot_data.index.name = 'id'
plot_data['yhat'] = X_short['oof']
plot_data['type'] = type_train

def plot_oof_preds(ctype, llim, ulim):
        plt.figure(figsize=(6,6))
        sns.scatterplot(x='scalar_coupling_constant',y='yhat',
                        data=plot_data.loc[plot_data['type']==ctype,
                        ['scalar_coupling_constant', 'yhat']]);
        plt.xlim((llim, ulim))
        plt.ylim((llim, ulim))
        plt.plot([llim, ulim], [llim, ulim])
        plt.xlabel('scalar_coupling_constant')
        plt.ylabel('predicted')
        plt.title(f'{ctype}', fontsize=18)
        plt.show()

plot_oof_preds('1JHC', 0, 250)
plot_oof_preds('1JHN', 0, 100)
plot_oof_preds('2JHC', -50, 50)
plot_oof_preds('2JHH', -50, 50)
plot_oof_preds('2JHN', -25, 25)
plot_oof_preds('3JHC', -25, 100)
plot_oof_preds('3JHH', -20, 20)
plot_oof_preds('3JHN', -10, 15)

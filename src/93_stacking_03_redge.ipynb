# %% [markdown]
# # Overview
# - スタッキングを試してみる

# %% [markdown]
# # Import everything I need :)

# %%
import warnings
warnings.filterwarnings('ignore')
import time
import multiprocessing
import glob
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn import linear_model
from fastprogress import progress_bar

# %% [markdown]
# # Preparation

# %%
nb = 75
isSmallSet = False
length = 10000
model_name = 'ridge'

# %%
pd.set_option('display.max_columns', 200)

# %%
file_path = '../input/champs-scalar-coupling/'
glob.glob(file_path + '*')
# Out:
# ['../input/champs-scalar-coupling/sample_submission.csv',
#  '../input/champs-scalar-coupling/mulliken_charges.csv',
#  '../input/champs-scalar-coupling/structures.csv',
#  '../input/champs-scalar-coupling/test_ob_charges_V7EstimatioofMullikenChargeswithOpenBabel.csv',
#  '../input/champs-scalar-coupling/magnetic_shielding_tensors.csv',
#  '../input/champs-scalar-coupling/nb33_train_dist-interaction.csv',
#  '../input/champs-scalar-coupling/dipole_moments.csv',
#  '../input/champs-scalar-coupling/nb29_fc_test_feature.csv',
#  '../input/champs-scalar-coupling/nb47_fc_train.csv',
#  '../input/champs-scalar-coupling/potential_energy.csv',
#  '../input/champs-scalar-coupling/nb33_test_dist-interaction.csv',
#  '../input/champs-scalar-coupling/nb29_fc_train_feature.csv',
#  '../input/champs-scalar-coupling/train.csv',
#  '../input/champs-scalar-coupling/scalar_coupling_contributions.csv',
#  '../input/champs-scalar-coupling/nb47_fc_test.csv',
#  '../input/champs-scalar-coupling/test.csv',
#  '../input/champs-scalar-coupling/train_ob_charges_V7EstimatioofMullikenChargeswithOpenBabel.csv']

# %%
# train
path = file_path + 'train.csv'
if isSmallSet:
    train = pd.read_csv(path) [:length]
else:
    train = pd.read_csv(path)
    
type_train = train.type.values

# %%
# train
path = file_path + 'test.csv'
if isSmallSet:
    test = pd.read_csv(path) [:length]
else:
    test = pd.read_csv(path)
    
type_test = test.type.values

# %% [markdown]
# ## myFunc
# **metrics**

# %%
def kaggle_metric(df, preds):
    df["prediction"] = preds
    maes = []
    for t in df.type.unique():
        y_true = df[df.type==t].scalar_coupling_constant.values
        y_pred = df[df.type==t].prediction.values
        mae = np.log(mean_absolute_error(y_true, y_pred))
        maes.append(mae)
    return np.mean(maes)

# %% [markdown]
# # Stacking

# %%
path_list = [
'nb54_{}_random_forest_regressor_-1.45569.csv',
'nb60_{}_lgb_-1.5330660525700779.csv',
'nb79_{}_extra_trees_regressor_-1.56760.csv',
'nb80_{}_extra_trees_regressor_-1.48000.csv',
'nb81_{}_bagging_regressor_-1.44452.csv',
'nb84_{}_extra_trees_regressor_-1.60943.csv',
'nb85_{}_extra_trees_regressor_-1.52972.csv',
'nb88_{}_lgb_-1.547953965914086.csv',
'nb91_{}_extra_trees_regressor_-1.47467.csv',
]

# %%
# oof
oofs = []
for path in path_list:
    if isSmallSet:
        df = pd.read_csv('./../output/' + path.format('oof'))[:length]
    else:
        df = pd.read_csv('./../output/' + path.format('oof'))
    oofs.append(df)

# %%
# sub
subs = []
for path in path_list:
    if isSmallSet:
        df = pd.read_csv('./../output/' + path.format('submission')).drop(['id'], axis=1)[:length]
    else:
        df = pd.read_csv('./../output/' + path.format('submission')).drop(['id'], axis=1)
    subs.append(df)

# %% [markdown]
# # Create train, test data

# %% [markdown]
# LabelEncode
# - `type`   = {2JHC, ...}

# %%
lbl = LabelEncoder()
lbl.fit(list(type_train) + list(type_test))
type_train_lbl = lbl.transform(type_train)
type_test_lbl = lbl.transform(type_test)

# %%
y = train.scalar_coupling_constant
X = pd.concat(oofs, axis=1)
X = pd.DataFrame(X.values, columns=path_list)
X_test = pd.concat(subs, axis=1)
X_test = pd.DataFrame(X_test.values, columns=path_list)

# %% [markdown]
# # Training model

# %% [markdown]
# **params**

# %%
# Configuration
MAX_ITER = 10000
RANDOM_STATE = 0

model_params_list = [
 {'alpha': 0.016490786888660246},
 {'alpha': 0.01948297047624237},
 {'alpha': 0.01181445773799895},
 {'alpha': 0.01},
 {'alpha': 0.17022936642711317},
 {'alpha': 0.9019291300867383},
 {'alpha': 1.2589254117941673},
 {'alpha': 0.5469291042181513}]

# %%
n_folds = 6
folds = KFold(n_splits=n_folds, shuffle=True)

# %%
def train_model(X, X_test, y, folds, model_params):
    model = linear_model.Ridge(**model_params, max_iter=MAX_ITER, random_state=RANDOM_STATE)  # <=================

    scores = []
    oof = np.zeros(len(X))  
    prediction = np.zeros(len(X))  
    result_dict = {}
    for fold_n, (train_idx, valid_idx) in enumerate(folds.split(X)):
        print(f'Fold {fold_n + 1} started at {time.ctime()}')
        model.fit(X.iloc[train_idx, :], y[train_idx])
        y_valid_pred = model.predict(X.iloc[valid_idx, :])
        y_train_pred = model.predict(X.iloc[train_idx, :])
        prediction = model.predict(X_test)
        oof[valid_idx] = y_valid_pred
        score = mean_absolute_error(y[valid_idx], y_valid_pred)
        score_train = mean_absolute_error(y[train_idx], y_train_pred)
        scores.append(score)

        print(f'fold {fold_n+1} train:{score_train :.5f} \t valid: {score :.5f}')
        print('')
    print('CV mean score    : {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    print('kaggle mean score: {0:.4f}'.format(np.log(np.mean(scores)))) 
    print('')
    
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    return result_dict

# %%
# %%time
# type ごとの学習 

X_short = pd.DataFrame({'ind': list(X.index), 'type': type_train, 'oof': [0] * len(X), 'target': y.values})
X_short_test = pd.DataFrame({'ind': list(X_test.index), 'type': type_test, 'prediction': [0] * len(X_test)})
for i, t in enumerate(np.unique(type_train)):
    idx = lbl.transform([t])[0]
    model_params = model_params_list[idx]
    print('*'*80)
    print(f'Training of type {t}')
    print('*'*80)
    X_t = X.loc[type_train == t]
    X_test_t = X_test.loc[type_test == t]
    y_t = X_short.loc[type_train == t, 'target'].values
    
    result_dict = train_model(X_t, X_test_t, y_t, folds, model_params)
    X_short.loc[type_train == t, 'oof'] = result_dict['oof']
    X_short_test.loc[type_test == t, 'prediction'] = result_dict['prediction']
    
    

print('')
print('===== finish =====')
X['scalar_coupling_constant'] = y
X['type'] = type_train
metric = kaggle_metric(X, X_short['oof'])
X = X.drop(['scalar_coupling_constant', 'prediction', 'type'], axis=1)
print('CV mean score(group log mae): {0:.4f}'.format(metric))
prediction = X_short_test['prediction']
# Out:
# ********************************************************************************
# Training of type 1JHC
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:31 2019
# fold 1 train:0.55089 	 valid: 0.55120
#
# Fold 2 started at Tue Aug 27 10:25:32 2019
# fold 2 train:0.55126 	 valid: 0.54949
#
# Fold 3 started at Tue Aug 27 10:25:32 2019
# fold 3 train:0.55065 	 valid: 0.55313
#
# Fold 4 started at Tue Aug 27 10:25:32 2019
# fold 4 train:0.55098 	 valid: 0.55097
#
# Fold 5 started at Tue Aug 27 10:25:32 2019
# fold 5 train:0.55097 	 valid: 0.55047
#
# Fold 6 started at Tue Aug 27 10:25:32 2019
# fold 6 train:0.55123 	 valid: 0.55085
#
# CV mean score    : 0.5510, std: 0.0011.
# kaggle mean score: -0.5960
#
# ********************************************************************************
# Training of type 1JHN
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:33 2019
# fold 1 train:0.28920 	 valid: 0.29034
#
# Fold 2 started at Tue Aug 27 10:25:33 2019
# fold 2 train:0.28810 	 valid: 0.29602
#
# Fold 3 started at Tue Aug 27 10:25:33 2019
# fold 3 train:0.28972 	 valid: 0.28884
#
# Fold 4 started at Tue Aug 27 10:25:33 2019
# fold 4 train:0.28966 	 valid: 0.28725
#
# Fold 5 started at Tue Aug 27 10:25:33 2019
# fold 5 train:0.28881 	 valid: 0.29129
#
# Fold 6 started at Tue Aug 27 10:25:33 2019
# fold 6 train:0.29060 	 valid: 0.28317
#
# CV mean score    : 0.2895, std: 0.0039.
# kaggle mean score: -1.2396
#
# ********************************************************************************
# Training of type 2JHC
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:34 2019
# fold 1 train:0.19445 	 valid: 0.19511
#
# Fold 2 started at Tue Aug 27 10:25:34 2019
# fold 2 train:0.19450 	 valid: 0.19561
#
# Fold 3 started at Tue Aug 27 10:25:34 2019
# fold 3 train:0.19453 	 valid: 0.19456
#
# Fold 4 started at Tue Aug 27 10:25:35 2019
# fold 4 train:0.19462 	 valid: 0.19473
#
# Fold 5 started at Tue Aug 27 10:25:35 2019
# fold 5 train:0.19459 	 valid: 0.19452
#
# Fold 6 started at Tue Aug 27 10:25:35 2019
# fold 6 train:0.19493 	 valid: 0.19314
#
# CV mean score    : 0.1946, std: 0.0008.
# kaggle mean score: -1.6368
#
# ********************************************************************************
# Training of type 2JHH
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:36 2019
# fold 1 train:0.12577 	 valid: 0.12680
#
# Fold 2 started at Tue Aug 27 10:25:36 2019
# fold 2 train:0.12605 	 valid: 0.12484
#
# Fold 3 started at Tue Aug 27 10:25:36 2019
# fold 3 train:0.12574 	 valid: 0.12659
#
# Fold 4 started at Tue Aug 27 10:25:36 2019
# fold 4 train:0.12572 	 valid: 0.12641
#
# Fold 5 started at Tue Aug 27 10:25:36 2019
# fold 5 train:0.12594 	 valid: 0.12521
#
# Fold 6 started at Tue Aug 27 10:25:36 2019
# fold 6 train:0.12593 	 valid: 0.12536
#
# CV mean score    : 0.1259, std: 0.0008.
# kaggle mean score: -2.0725
#
# ********************************************************************************
# Training of type 2JHN
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:37 2019
# fold 1 train:0.10630 	 valid: 0.10777
#
# Fold 2 started at Tue Aug 27 10:25:37 2019
# fold 2 train:0.10687 	 valid: 0.10343
#
# Fold 3 started at Tue Aug 27 10:25:37 2019
# fold 3 train:0.10583 	 valid: 0.10788
#
# Fold 4 started at Tue Aug 27 10:25:37 2019
# fold 4 train:0.10649 	 valid: 0.10547
#
# Fold 5 started at Tue Aug 27 10:25:37 2019
# fold 5 train:0.10621 	 valid: 0.10762
#
# Fold 6 started at Tue Aug 27 10:25:37 2019
# fold 6 train:0.10623 	 valid: 0.10594
#
# CV mean score    : 0.1064, std: 0.0016.
# kaggle mean score: -2.2410
#
# ********************************************************************************
# Training of type 3JHC
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:38 2019
# fold 1 train:0.20369 	 valid: 0.20372
#
# Fold 2 started at Tue Aug 27 10:25:38 2019
# fold 2 train:0.20394 	 valid: 0.20322
#
# Fold 3 started at Tue Aug 27 10:25:38 2019
# fold 3 train:0.20362 	 valid: 0.20511
#
# Fold 4 started at Tue Aug 27 10:25:39 2019
# fold 4 train:0.20334 	 valid: 0.20385
#
# Fold 5 started at Tue Aug 27 10:25:39 2019
# fold 5 train:0.20346 	 valid: 0.20306
#
# Fold 6 started at Tue Aug 27 10:25:39 2019
# fold 6 train:0.20355 	 valid: 0.20270
#
# CV mean score    : 0.2036, std: 0.0008.
# kaggle mean score: -1.5915
#
# ********************************************************************************
# Training of type 3JHH
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:40 2019
# fold 1 train:0.12146 	 valid: 0.12103
#
# Fold 2 started at Tue Aug 27 10:25:40 2019
# fold 2 train:0.12124 	 valid: 0.12212
#
# Fold 3 started at Tue Aug 27 10:25:40 2019
# fold 3 train:0.12146 	 valid: 0.12139
#
# Fold 4 started at Tue Aug 27 10:25:40 2019
# fold 4 train:0.12137 	 valid: 0.12138
#
# Fold 5 started at Tue Aug 27 10:25:40 2019
# fold 5 train:0.12141 	 valid: 0.12132
#
# Fold 6 started at Tue Aug 27 10:25:41 2019
# fold 6 train:0.12144 	 valid: 0.12118
#
# CV mean score    : 0.1214, std: 0.0003.
# kaggle mean score: -2.1086
#
# ********************************************************************************
# Training of type 3JHN
# ********************************************************************************
# Fold 1 started at Tue Aug 27 10:25:41 2019
# fold 1 train:0.08864 	 valid: 0.08861
#
# Fold 2 started at Tue Aug 27 10:25:41 2019
# fold 2 train:0.08853 	 valid: 0.08864
#
# Fold 3 started at Tue Aug 27 10:25:41 2019
# fold 3 train:0.08876 	 valid: 0.08809
#
# Fold 4 started at Tue Aug 27 10:25:41 2019
# fold 4 train:0.08845 	 valid: 0.08957
#
# Fold 5 started at Tue Aug 27 10:25:41 2019
# fold 5 train:0.08827 	 valid: 0.08984
#
# Fold 6 started at Tue Aug 27 10:25:41 2019
# fold 6 train:0.08898 	 valid: 0.08700
#
# CV mean score    : 0.0886, std: 0.0009.
# kaggle mean score: -2.4233
#
#
# ===== finish =====
# CV mean score(group log mae): -1.7387
# CPU times: user 40.8 s, sys: 27.5 s, total: 1min 8s
# Wall time: 27.7 s

# %% [markdown]
# # Save

# %% [markdown]
# **submission**

# %%
# path_submittion = './output/' + 'nb{}_submission_lgb_{}.csv'.format(nb, metric)
path_submittion = f'../output/nb{nb}_stack_submission_{model_name}_{metric :.5f}.csv'
print(f'save pash: {path_submittion}')

# %%
submittion = pd.read_csv('../input/champs-scalar-coupling/sample_submission.csv')
# submittion = pd.read_csv('./input/champs-scalar-coupling/sample_submission.csv')[::100]
submittion['scalar_coupling_constant'] = prediction
if isSmallSet:
    pass
else:
    submittion.to_csv(path_submittion, index=False)

# %% [markdown]
# ---
# **result**

# %%
path_oof = f'../output/nb{nb}_stack_oof_{model_name}_{metric :.5f}.csv'
print(f'save pash: {path_oof}')

# %%
oof = pd.DataFrame(X_short['oof'])
if isSmallSet:
    pass
else:
    oof.to_csv(path_oof, index=False)

# %% [markdown]
# # analysis

# %%
plot_data = pd.DataFrame(y)
plot_data.index.name = 'id'
plot_data['yhat'] = X_short['oof']
plot_data['type'] = type_train

def plot_oof_preds(ctype, llim, ulim):
        plt.figure(figsize=(6,6))
        sns.scatterplot(x='scalar_coupling_constant',y='yhat',
                        data=plot_data.loc[plot_data['type']==ctype,
                        ['scalar_coupling_constant', 'yhat']]);
        plt.xlim((llim, ulim))
        plt.ylim((llim, ulim))
        plt.plot([llim, ulim], [llim, ulim])
        plt.xlabel('scalar_coupling_constant')
        plt.ylabel('predicted')
        plt.title(f'{ctype}', fontsize=18)
        plt.show()

plot_oof_preds('1JHC', 0, 250)
plot_oof_preds('1JHN', 0, 100)
plot_oof_preds('2JHC', -50, 50)
plot_oof_preds('2JHH', -50, 50)
plot_oof_preds('2JHN', -25, 25)
plot_oof_preds('3JHC', -25, 60)
plot_oof_preds('3JHH', -20, 20)
plot_oof_preds('3JHN', -10, 15)

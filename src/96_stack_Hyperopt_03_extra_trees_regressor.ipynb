# %% [markdown]
# # Introduction
# - extra trees regressorでstackingを行う
# - hyperopt でチューニングも行う

# %% [markdown]
# # Import everything I need :)

# %%
import warnings
warnings.filterwarnings('ignore')
import time
import multiprocessing
import glob
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn import linear_model
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, BaggingRegressor
from functools import partial
from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK, STATUS_RUNNING
from fastprogress import progress_bar

# %% [markdown]
# # Preparation

# %%
nb = 96
isSmallSet = False
length = 2000
model_name = 'extra_trees_regressor'

# %%
pd.set_option('display.max_columns', 200)

# %%
file_path = '../input/champs-scalar-coupling/'
glob.glob(file_path + '*')
# Out:
# ['../input/champs-scalar-coupling/scalar_coupling_contributions.csv',
#  '../input/champs-scalar-coupling/magnetic_shielding_tensors.csv',
#  '../input/champs-scalar-coupling/structures.csv',
#  '../input/champs-scalar-coupling/test.csv',
#  '../input/champs-scalar-coupling/dipole_moments.csv',
#  '../input/champs-scalar-coupling/potential_energy.csv',
#  '../input/champs-scalar-coupling/sample_submission.csv',
#  '../input/champs-scalar-coupling/nb47_fc_train.csv',
#  '../input/champs-scalar-coupling/train.csv',
#  '../input/champs-scalar-coupling/nb33_train_dist-interaction.csv',
#  '../input/champs-scalar-coupling/test_ob_charges_V7EstimatioofMullikenChargeswithOpenBabel.csv',
#  '../input/champs-scalar-coupling/nb29_fc_test_feature.csv',
#  '../input/champs-scalar-coupling/train_ob_charges_V7EstimatioofMullikenChargeswithOpenBabel.csv',
#  '../input/champs-scalar-coupling/nb33_test_dist-interaction.csv',
#  '../input/champs-scalar-coupling/mulliken_charges.csv',
#  '../input/champs-scalar-coupling/nb47_fc_test.csv',
#  '../input/champs-scalar-coupling/nb29_fc_train_feature.csv']

# %%
# train
path = file_path + 'train.csv'
if isSmallSet:
    train = pd.read_csv(path) [:length]
else:
    train = pd.read_csv(path)
    
type_train = train.type.values

# %%
# train
path = file_path + 'test.csv'
if isSmallSet:
    test = pd.read_csv(path) [:length]
else:
    test = pd.read_csv(path)
    
type_test = test.type.values

# %% [markdown]
# ## myFunc
# **metrics**

# %%
def kaggle_metric(df, preds):
    df["prediction"] = preds
    maes = []
    for t in df.type.unique():
        y_true = df[df.type==t].scalar_coupling_constant.values
        y_pred = df[df.type==t].prediction.values
        mae = np.log(mean_absolute_error(y_true, y_pred))
        maes.append(mae)
    return np.mean(maes)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                c_prec = df[col].apply(lambda x: np.finfo(x).precision).max()
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max and c_prec == np.finfo(np.float16).precision:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max and c_prec == np.finfo(np.float32).precision:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %% [markdown]
# # Stacking

# %%
path_list = [
'nb60_{}_lgb_-1.5330660525700779.csv',
'nb79_{}_extra_trees_regressor_-1.56760.csv',
'nb80_{}_extra_trees_regressor_-1.48000.csv',
'nb81_{}_bagging_regressor_-1.44452.csv',
'nb82_{}_bagging_regressor_-1.36181.csv',
'nb84_{}_extra_trees_regressor_-1.60943.csv',
'nb85_{}_extra_trees_regressor_-1.52972.csv',
'nb88_{}_lgb_-1.547953965914086.csv',
'nb91_{}_extra_trees_regressor_-1.47467.csv',
]

# %%
# oof
oofs = []
for path in path_list:
    if isSmallSet:
        df = pd.read_csv('./../output/' + path.format('oof'))[:length]
    else:
        df = pd.read_csv('./../output/' + path.format('oof'))
        df = reduce_mem_usage(df)
    oofs.append(df)
# Out:
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)
# Mem. usage decreased to 35.54 Mb (0.0% reduction)

# %%
# sub
subs = []
for path in path_list:
    if isSmallSet:
        df = pd.read_csv('./../output/' + path.format('submission')).drop(['id'], axis=1)[:length]
    else:
        df = pd.read_csv('./../output/' + path.format('submission')).drop(['id'], axis=1)
        df = reduce_mem_usage(df)
    subs.append(df)
# Out:
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)
# Mem. usage decreased to 19.12 Mb (0.0% reduction)

# %% [markdown]
# <br>
# <br>
# plot

# %%
oof_list = [df.oof.values for df in oofs ] 
model_names = path_list
# types = lbl.inverse_transform(X['type'])
types = type_train

def plot_oof_preds(ctype, llim, ulim):
    fig, axs = plt.subplots(1, len(model_names), figsize=(5*len(model_names), 5))
    axs = axs.ravel()
    for i in range(len(model_names)):
        model_name = model_names[i]
        t_idx = types==ctype
        y = train.scalar_coupling_constant.values
        axs[i].scatter(y[t_idx], oof_list[i][t_idx])
        axs[i].set_xlim((llim, ulim))
        axs[i].set_ylim((llim, ulim))
        axs[i].plot([llim, ulim], [llim, ulim])
        axs[i].set_xlabel('scalar_coupling_constant')
        axs[i].set_ylabel('predicted')
        axs[i].set_title(f'{ctype}  {model_names[i]}', fontsize=12)
        
plot_oof_preds('1JHC', 0, 250)
plot_oof_preds('1JHN', 0, 100)
plot_oof_preds('2JHC', -50, 50)
plot_oof_preds('2JHH', -50, 25)
plot_oof_preds('2JHN', -10, 25)
plot_oof_preds('3JHC', -25, 100)
plot_oof_preds('3JHH', -10, 20)
plot_oof_preds('3JHN', -10, 15)

# %% [markdown]
# # Create train, test data

# %% [markdown]
# LabelEncode
# - `type`   = {2JHC, ...}

# %%
lbl = LabelEncoder()
lbl.fit(list(type_train) + list(type_test))
type_train_lbl = lbl.transform(type_train)
type_test_lbl = lbl.transform(type_test)

# %%
y = train.scalar_coupling_constant
X = pd.concat(oofs, axis=1)
X = pd.DataFrame(X.values, columns=path_list)
X_test = pd.concat(subs, axis=1)
X_test = pd.DataFrame(X_test.values, columns=path_list)
X['type'] = type_train_lbl
X_test['type'] = type_test_lbl

# %%
del train, test

# %%
gc.collect()
# Out:
# 11991

# %% [markdown]
# # Hyperopt

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,
                                                  y,
                                                  test_size = 0.30, 
                                                  random_state = 0)

# %%
# Define searched space
hyper_space = {'n_estimators': hp.choice('n_estimators', [10, 50, 100, 200, 400]),
               'max_depth': hp.choice('max_depth', [30, 50, 70])}

# Seting the number of Evals
MAX_EVALS= 13

# %%
# %%time
# type ごとの学習 

best_params_list = []
# for t in sorted(X_train['type'].unique()):
for t in sorted(np.unique(type_train_lbl)):
    print('*'*80)
    print(f'- Training of type {t}')
    print('*'*80)
    X_t_train = X_train.loc[X_train['type'] == t]
    X_t_valid = X_valid.loc[X_valid['type'] == t]
    y_t_train = y_train[X_train['type'] == t]
    y_t_valid = y_valid[X_valid['type'] == t]
    
    
    # evaluate_metric
    def evaluate_metric(params):
        model = ExtraTreesRegressor(**params, random_state=42, n_jobs=-1)  # <=======================
        model.fit(X_t_train, y_t_train)

        pred = model.predict(X_t_valid)
        y_t_train_pred = model.predict(X_t_train)

        _X_t_valid = X_t_valid.copy()
        _X_t_valid['scalar_coupling_constant'] = y_t_valid
        cv_score = kaggle_metric(_X_t_valid, pred)
        _X_t_valid = _X_t_valid.drop(['scalar_coupling_constant'], axis=1)

#         print(f'mae(valid): {mean_absolute_error(y_t_valid, pred)}')
        
        print(params)
        print(f'training l1: {mean_absolute_error(y_t_train, y_t_train_pred) :.5f}	\t valid l1: {mean_absolute_error(y_t_valid, pred) :.5f} ')
        print(f'cv_score: {cv_score}')
        print('-'*80)
        print('\n')

        return {
            'loss': cv_score,
            'status': STATUS_OK,
            'stats_running': STATUS_RUNNING
        }
    
    
    # hyperopt
    # Trail
    trials = Trials()

    # Set algoritm parameters
    algo = partial(tpe.suggest, 
                   n_startup_jobs=1)


    # Fit Tree Parzen Estimator
    best_vals = fmin(evaluate_metric, space=hyper_space, verbose=1,
                     algo=algo, max_evals=MAX_EVALS, trials=trials)

    # Print best parameters
    best_params = space_eval(hyper_space, best_vals)
    best_params_list.append(best_params)
    print("BEST PARAMETERS: " + str(best_params))
    print('')
# Out:
# ********************************************************************************
# - Training of type 0
# ********************************************************************************
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00015		 valid l1: 0.53528
# cv_score: -0.6249728320901976
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00015		 valid l1: 0.53528
# cv_score: -0.6249728320901976
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 50}
# training l1: 0.00018		 valid l1: 0.54174
# cv_score: -0.6129713696993526
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.08216		 valid l1: 0.56541
# cv_score: -0.570202587024773
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 100}
# training l1: 0.00000		 valid l1: 0.53832
# cv_score: -0.6193033804152908
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 200}
# training l1: 0.00016		 valid l1: 0.53641
# cv_score: -0.6228534389280078
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00015		 valid l1: 0.53528
# cv_score: -0.6249728320901979
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.07552		 valid l1: 0.53410
# cv_score: -0.6271786127162153
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.07552		 valid l1: 0.53410
# cv_score: -0.6271786127162152
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.07703		 valid l1: 0.53675
# cv_score: -0.622217382039878
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 200}
# training l1: 0.07565		 valid l1: 0.53494
# cv_score: -0.6256027842572455
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 50}
# training l1: 0.00000		 valid l1: 0.54220
# cv_score: -0.6121245534445707
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.08216		 valid l1: 0.56541
# cv_score: -0.5702025870247728
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [04:57<00:00, 15.52s/it, best loss: -0.6271786127162153]
# BEST PARAMETERS: {'max_depth': 30, 'n_estimators': 400}
#
# ********************************************************************************
# - Training of type 1
# ********************************************************************************
# {'max_depth': 50, 'n_estimators': 10}
# training l1: 0.00000		 valid l1: 0.31022
# cv_score: -1.1704837214357515
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 10}
# training l1: 0.00000		 valid l1: 0.31022
# cv_score: -1.1704837214357517
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 10}
# training l1: 0.00000		 valid l1: 0.31022
# cv_score: -1.1704837214357515
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00090		 valid l1: 0.29232
# cv_score: -1.2299113030772106
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00090		 valid l1: 0.29232
# cv_score: -1.229911303077211
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 50}
# training l1: 0.00099		 valid l1: 0.29486
# cv_score: -1.221242113146227
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.00097		 valid l1: 0.29367
# cv_score: -1.225289331455291
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 200}
# training l1: 0.00000		 valid l1: 0.29328
# cv_score: -1.2266326687163158
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00090		 valid l1: 0.29232
# cv_score: -1.2299113030772104
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00090		 valid l1: 0.29232
# cv_score: -1.2299113030772104
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.00097		 valid l1: 0.29367
# cv_score: -1.2252893314552915
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 200}
# training l1: 0.00000		 valid l1: 0.29328
# cv_score: -1.2266326687163165
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.29264
# cv_score: -1.2288016201170078
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [00:20<00:00,  1.93s/it, best loss: -1.229911303077211]
# BEST PARAMETERS: {'max_depth': 30, 'n_estimators': 400}
#
# ********************************************************************************
# - Training of type 2
# ********************************************************************************
# {'max_depth': 70, 'n_estimators': 50}
# training l1: 0.00000		 valid l1: 0.18503
# cv_score: -1.6872219753297044
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 50}
# training l1: 0.00000		 valid l1: 0.18503
# cv_score: -1.6872219753297044
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 100}
# training l1: 0.00000		 valid l1: 0.18359
# cv_score: -1.6950427037169273
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 100}
# training l1: 0.00052		 valid l1: 0.18360
# cv_score: -1.6949824435322196
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.04963		 valid l1: 0.18168
# cv_score: -1.7054905992268372
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.04963		 valid l1: 0.18168
# cv_score: -1.7054905992268372
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.05038		 valid l1: 0.19154
# cv_score: -1.6526525302548525
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 200}
# training l1: 0.04974		 valid l1: 0.18196
# cv_score: -1.7039728829642122
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.04963		 valid l1: 0.18168
# cv_score: -1.705490599226837
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00049		 valid l1: 0.18247
# cv_score: -1.7011652246667006
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.05038		 valid l1: 0.19154
# cv_score: -1.6526525302548525
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.04963		 valid l1: 0.18168
# cv_score: -1.7054905992268372
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 200}
# training l1: 0.00049		 valid l1: 0.18280
# cv_score: -1.6993725302983695
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [08:00<00:00, 39.79s/it, best loss: -1.7054905992268372]
# BEST PARAMETERS: {'max_depth': 30, 'n_estimators': 400}
#
# ********************************************************************************
# - Training of type 3
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.01625		 valid l1: 0.12152
# cv_score: -2.1076835680821153
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.01625		 valid l1: 0.12152
# cv_score: -2.1076835680821153
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.01654		 valid l1: 0.12763
# cv_score: -2.0586511480068768
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 50}
# training l1: 0.00004		 valid l1: 0.12260
# cv_score: -2.0987879782608165
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.12124
# cv_score: -2.1100199354399494
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.12124
# cv_score: -2.1100199354399494
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.12124
# cv_score: -2.110019935439949
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 200}
# training l1: 0.00000		 valid l1: 0.12149
# cv_score: -2.107900942425032
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00003		 valid l1: 0.12119
# cv_score: -2.110381001162811
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00003		 valid l1: 0.12119
# cv_score: -2.110381001162811
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 50}
# training l1: 0.00004		 valid l1: 0.12260
# cv_score: -2.0987879782608165
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 200}
# training l1: 0.00004		 valid l1: 0.12140
# cv_score: -2.108690119584663
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 10}
# training l1: 0.00005		 valid l1: 0.12937
# cv_score: -2.04511376390433
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [02:35<00:00, 10.72s/it, best loss: -2.110381001162811]
# BEST PARAMETERS: {'max_depth': 50, 'n_estimators': 400}
#
# ********************************************************************************
# - Training of type 4
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.00540		 valid l1: 0.10871
# cv_score: -2.2190806174530167
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.00540		 valid l1: 0.10871
# cv_score: -2.2190806174530167
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 200}
# training l1: 0.00468		 valid l1: 0.10158
# cv_score: -2.286860673761635
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 200}
# training l1: 0.00000		 valid l1: 0.10179
# cv_score: -2.2848026601589404
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 200}
# training l1: 0.00001		 valid l1: 0.10183
# cv_score: -2.284472767881043
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 50}
# training l1: 0.00472		 valid l1: 0.10256
# cv_score: -2.277309431173562
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00468		 valid l1: 0.10140
# cv_score: -2.288700942091992
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.10154
# cv_score: -2.2872745436834174
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 100}
# training l1: 0.00001		 valid l1: 0.10221
# cv_score: -2.280756683228986
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00468		 valid l1: 0.10140
# cv_score: -2.288700942091992
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00468		 valid l1: 0.10140
# cv_score: -2.2887009420919924
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 100}
# training l1: 0.00001		 valid l1: 0.10221
# cv_score: -2.280756683228986
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.10154
# cv_score: -2.2872745436834174
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [00:56<00:00,  5.73s/it, best loss: -2.2887009420919924]
# BEST PARAMETERS: {'max_depth': 30, 'n_estimators': 400}
#
# ********************************************************************************
# - Training of type 5
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 200}
# training l1: 0.05226		 valid l1: 0.18948
# cv_score: -1.6634848966004614
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 200}
# training l1: 0.05226		 valid l1: 0.18948
# cv_score: -1.6634848966004614
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.05730		 valid l1: 0.19897
# cv_score: -1.614612348588704
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 50}
# training l1: 0.00000		 valid l1: 0.19246
# cv_score: -1.647866715394764
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 200}
# training l1: 0.00026		 valid l1: 0.19034
# cv_score: -1.6589418739115214
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.05270		 valid l1: 0.19006
# cv_score: -1.6604212926007604
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.18990
# cv_score: -1.6612611540181472
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 200}
# training l1: 0.00026		 valid l1: 0.19034
# cv_score: -1.6589418739115214
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.05270		 valid l1: 0.19006
# cv_score: -1.6604212926007604
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.05285		 valid l1: 0.18913
# cv_score: -1.665343903575074
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.05285		 valid l1: 0.18913
# cv_score: -1.665343903575074
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00026		 valid l1: 0.18989
# cv_score: -1.6612980083343758
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 50}
# training l1: 0.00000		 valid l1: 0.19246
# cv_score: -1.647866715394764
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [13:37<00:00, 67.58s/it, best loss: -1.665343903575074]
# BEST PARAMETERS: {'max_depth': 30, 'n_estimators': 400}
#
# ********************************************************************************
# - Training of type 6
# ********************************************************************************
# {'max_depth': 50, 'n_estimators': 100}
# training l1: 0.00003		 valid l1: 0.11406
# cv_score: -2.171000890692635
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 100}
# training l1: 0.00003		 valid l1: 0.11406
# cv_score: -2.171000890692635
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.01252		 valid l1: 0.11316
# cv_score: -2.1789458310384906
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.01252		 valid l1: 0.11316
# cv_score: -2.1789458310384906
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 50}
# training l1: 0.01278		 valid l1: 0.11449
# cv_score: -2.167300049754594
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 200}
# training l1: 0.00000		 valid l1: 0.11364
# cv_score: -2.174719828840291
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.01345		 valid l1: 0.12068
# cv_score: -2.1146235426030215
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.11343
# cv_score: -2.1765342741190343
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.01252		 valid l1: 0.11316
# cv_score: -2.1789458310384906
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.01252		 valid l1: 0.11316
# cv_score: -2.1789458310384906
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 200}
# training l1: 0.00000		 valid l1: 0.11364
# cv_score: -2.1747198288402907
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 10}
# training l1: 0.00003		 valid l1: 0.12178
# cv_score: -2.105566827883469
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 50}
# training l1: 0.01278		 valid l1: 0.11449
# cv_score: -2.167300049754594
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [04:05<00:00, 14.65s/it, best loss: -2.1789458310384906]
# BEST PARAMETERS: {'max_depth': 30, 'n_estimators': 400}
#
# ********************************************************************************
# - Training of type 7
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00542		 valid l1: 0.08103
# cv_score: -2.512995431448454
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 400}
# training l1: 0.00542		 valid l1: 0.08103
# cv_score: -2.512995431448454
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 100}
# training l1: 0.00555		 valid l1: 0.08158
# cv_score: -2.5062090844453566
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 10}
# training l1: 0.00000		 valid l1: 0.08705
# cv_score: -2.4413125275518985
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 400}
# training l1: 0.00001		 valid l1: 0.08112
# cv_score: -2.511802946769254
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 200}
# training l1: 0.00546		 valid l1: 0.08120
# cv_score: -2.5108142759324705
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 50}
# training l1: 0.00002		 valid l1: 0.08240
# cv_score: -2.496131611409356
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.08115
# cv_score: -2.511426013033318
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 10}
# training l1: 0.00582		 valid l1: 0.08695
# cv_score: -2.4424365947127975
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 50}
# training l1: 0.00549		 valid l1: 0.08227
# cv_score: -2.497748420734901
# --------------------------------------------------------------------------------
# {'max_depth': 50, 'n_estimators': 100}
# training l1: 0.00002		 valid l1: 0.08169
# cv_score: -2.5048662518990548
# --------------------------------------------------------------------------------
# {'max_depth': 30, 'n_estimators': 200}
# training l1: 0.00546		 valid l1: 0.08120
# cv_score: -2.5108142759324705
# --------------------------------------------------------------------------------
# {'max_depth': 70, 'n_estimators': 400}
# training l1: 0.00000		 valid l1: 0.08115
# cv_score: -2.511426013033318
# --------------------------------------------------------------------------------
# 100%|██████████| 13/13 [01:00<00:00,  4.56s/it, best loss: -2.512995431448454]
# BEST PARAMETERS: {'max_depth': 30, 'n_estimators': 400}
#
# CPU times: user 12h 57min 15s, sys: 20min 31s, total: 13h 17min 47s
# Wall time: 35min 35s

# %%
best_params_list
# Out:
# [{'max_depth': 30, 'n_estimators': 400},
#  {'max_depth': 30, 'n_estimators': 400},
#  {'max_depth': 30, 'n_estimators': 400},
#  {'max_depth': 50, 'n_estimators': 400},
#  {'max_depth': 30, 'n_estimators': 400},
#  {'max_depth': 30, 'n_estimators': 400},
#  {'max_depth': 30, 'n_estimators': 400},
#  {'max_depth': 30, 'n_estimators': 400}]

# %% [markdown]
# # Training model

# %% [markdown]
# **params**

# %%
# Configuration
RANDOM_STATE = 0

model_params_list = best_params_list

# %%
n_folds = 6
folds = KFold(n_splits=n_folds, shuffle=True)

# %%
def train_model(X, X_test, y, folds, model_params):

    scores = []
    oof = np.zeros(len(X))  
    prediction = np.zeros(len(X))  
    result_dict = {}
    for fold_n, (train_idx, valid_idx) in enumerate(folds.split(X)):
        model = ExtraTreesRegressor(**model_params, n_jobs=-1, random_state=RANDOM_STATE)  # <=================
        print(f'Fold {fold_n + 1} started at {time.ctime()}')
        model.fit(X.iloc[train_idx, :], y[train_idx])
        y_valid_pred = model.predict(X.iloc[valid_idx, :])
        y_train_pred = model.predict(X.iloc[train_idx, :])
        prediction = model.predict(X_test)
        oof[valid_idx] = y_valid_pred
        score = mean_absolute_error(y[valid_idx], y_valid_pred)
        score_train = mean_absolute_error(y[train_idx], y_train_pred)
        scores.append(score)

        print(f'fold {fold_n+1} train:{score_train :.5f} \t valid: {score :.5f}')
        print('')
    print('CV mean score    : {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    print('kaggle mean score: {0:.4f}'.format(np.log(np.mean(scores)))) 
    print('')
    
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    return result_dict

# %%
# %%time
# type ごとの学習 

X_short = pd.DataFrame({'ind': list(X.index), 'type': type_train, 'oof': [0] * len(X), 'target': y.values})
X_short_test = pd.DataFrame({'ind': list(X_test.index), 'type': type_test, 'prediction': [0] * len(X_test)})
for i, t in enumerate(np.unique(type_train)):
    idx = lbl.transform([t])[0]
    model_params = model_params_list[idx]
    print('*'*80)
    print(f'Training of type {t}, {idx}')
    print('*'*80)
    print(model_params)
    X_t = X.loc[type_train == t]
    X_test_t = X_test.loc[type_test == t]
    y_t = X_short.loc[type_train == t, 'target'].values
    
    result_dict = train_model(X_t, X_test_t, y_t, folds, model_params)
    X_short.loc[type_train == t, 'oof'] = result_dict['oof']
    X_short_test.loc[type_test == t, 'prediction'] = result_dict['prediction']
    
    

print('')
print('===== finish =====')
X['scalar_coupling_constant'] = y
metric = kaggle_metric(X, X_short['oof'])
X = X.drop(['scalar_coupling_constant', 'prediction'], axis=1)
print('CV mean score(group log mae): {0:.4f}'.format(metric))
prediction = X_short_test['prediction']
# Out:
# ********************************************************************************
# Training of type 1JHC, 0
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 11:58:16 2019
# fold 1 train:0.08407 	 valid: 0.53658
#
# Fold 2 started at Wed Aug 28 11:59:12 2019
# fold 2 train:0.08476 	 valid: 0.53483
#
# Fold 3 started at Wed Aug 28 12:00:08 2019
# fold 3 train:0.08465 	 valid: 0.53368
#
# Fold 4 started at Wed Aug 28 12:00:51 2019
# fold 4 train:0.08384 	 valid: 0.53773
#
# Fold 5 started at Wed Aug 28 12:01:35 2019
# fold 5 train:0.08467 	 valid: 0.53354
#
# Fold 6 started at Wed Aug 28 12:02:21 2019
# fold 6 train:0.08442 	 valid: 0.53430
#
# CV mean score    : 0.5351, std: 0.0015.
# kaggle mean score: -0.6253
#
# ********************************************************************************
# Training of type 1JHN, 1
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 12:03:11 2019
# fold 1 train:0.00124 	 valid: 0.29085
#
# Fold 2 started at Wed Aug 28 12:03:13 2019
# fold 2 train:0.00121 	 valid: 0.28974
#
# Fold 3 started at Wed Aug 28 12:03:16 2019
# fold 3 train:0.00121 	 valid: 0.29796
#
# Fold 4 started at Wed Aug 28 12:03:19 2019
# fold 4 train:0.00120 	 valid: 0.29722
#
# Fold 5 started at Wed Aug 28 12:03:22 2019
# fold 5 train:0.00121 	 valid: 0.29708
#
# Fold 6 started at Wed Aug 28 12:03:25 2019
# fold 6 train:0.00126 	 valid: 0.28767
#
# CV mean score    : 0.2934, std: 0.0041.
# kaggle mean score: -1.2262
#
# ********************************************************************************
# Training of type 2JHC, 2
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 12:03:29 2019
# fold 1 train:0.05347 	 valid: 0.18058
#
# Fold 2 started at Wed Aug 28 12:05:02 2019
# fold 2 train:0.05361 	 valid: 0.18109
#
# Fold 3 started at Wed Aug 28 12:06:39 2019
# fold 3 train:0.05363 	 valid: 0.18128
#
# Fold 4 started at Wed Aug 28 12:07:48 2019
# fold 4 train:0.05378 	 valid: 0.18000
#
# Fold 5 started at Wed Aug 28 12:08:57 2019
# fold 5 train:0.05346 	 valid: 0.18123
#
# Fold 6 started at Wed Aug 28 12:10:10 2019
# fold 6 train:0.05353 	 valid: 0.18141
#
# CV mean score    : 0.1809, std: 0.0005.
# kaggle mean score: -1.7096
#
# ********************************************************************************
# Training of type 2JHH, 3
# ********************************************************************************
# {'max_depth': 50, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 12:11:53 2019
# fold 1 train:0.00005 	 valid: 0.12068
#
# Fold 2 started at Wed Aug 28 12:12:30 2019
# fold 2 train:0.00005 	 valid: 0.12033
#
# Fold 3 started at Wed Aug 28 12:12:57 2019
# fold 3 train:0.00005 	 valid: 0.11994
#
# Fold 4 started at Wed Aug 28 12:13:25 2019
# fold 4 train:0.00005 	 valid: 0.12180
#
# Fold 5 started at Wed Aug 28 12:13:52 2019
# fold 5 train:0.00005 	 valid: 0.12021
#
# Fold 6 started at Wed Aug 28 12:14:19 2019
# fold 6 train:0.00005 	 valid: 0.12244
#
# CV mean score    : 0.1209, std: 0.0009.
# kaggle mean score: -2.1128
#
# ********************************************************************************
# Training of type 2JHN, 4
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 12:14:47 2019
# fold 1 train:0.00553 	 valid: 0.10062
#
# Fold 2 started at Wed Aug 28 12:14:54 2019
# fold 2 train:0.00560 	 valid: 0.10071
#
# Fold 3 started at Wed Aug 28 12:15:00 2019
# fold 3 train:0.00548 	 valid: 0.10123
#
# Fold 4 started at Wed Aug 28 12:15:07 2019
# fold 4 train:0.00558 	 valid: 0.10302
#
# Fold 5 started at Wed Aug 28 12:15:13 2019
# fold 5 train:0.00551 	 valid: 0.09987
#
# Fold 6 started at Wed Aug 28 12:15:20 2019
# fold 6 train:0.00554 	 valid: 0.10043
#
# CV mean score    : 0.1010, std: 0.0010.
# kaggle mean score: -2.2928
#
# ********************************************************************************
# Training of type 3JHC, 5
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 12:15:26 2019
# fold 1 train:0.05767 	 valid: 0.18866
#
# Fold 2 started at Wed Aug 28 12:17:40 2019
# fold 2 train:0.05789 	 valid: 0.18885
#
# Fold 3 started at Wed Aug 28 12:19:42 2019
# fold 3 train:0.05761 	 valid: 0.18945
#
# Fold 4 started at Wed Aug 28 12:21:27 2019
# fold 4 train:0.05764 	 valid: 0.18869
#
# Fold 5 started at Wed Aug 28 12:23:38 2019
# fold 5 train:0.05773 	 valid: 0.18844
#
# Fold 6 started at Wed Aug 28 12:26:01 2019
# fold 6 train:0.05790 	 valid: 0.18828
#
# CV mean score    : 0.1887, std: 0.0004.
# kaggle mean score: -1.6674
#
# ********************************************************************************
# Training of type 3JHH, 6
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 12:28:12 2019
# fold 1 train:0.01421 	 valid: 0.11272
#
# Fold 2 started at Wed Aug 28 12:28:48 2019
# fold 2 train:0.01405 	 valid: 0.11294
#
# Fold 3 started at Wed Aug 28 12:29:25 2019
# fold 3 train:0.01419 	 valid: 0.11387
#
# Fold 4 started at Wed Aug 28 12:30:01 2019
# fold 4 train:0.01412 	 valid: 0.11306
#
# Fold 5 started at Wed Aug 28 12:30:36 2019
# fold 5 train:0.01411 	 valid: 0.11356
#
# Fold 6 started at Wed Aug 28 12:31:11 2019
# fold 6 train:0.01404 	 valid: 0.11290
#
# CV mean score    : 0.1132, std: 0.0004.
# kaggle mean score: -2.1788
#
# ********************************************************************************
# Training of type 3JHN, 7
# ********************************************************************************
# {'max_depth': 30, 'n_estimators': 400}
# Fold 1 started at Wed Aug 28 12:31:48 2019
# fold 1 train:0.00615 	 valid: 0.07921
#
# Fold 2 started at Wed Aug 28 12:31:57 2019
# fold 2 train:0.00616 	 valid: 0.08037
#
# Fold 3 started at Wed Aug 28 12:32:05 2019
# fold 3 train:0.00612 	 valid: 0.08288
#
# Fold 4 started at Wed Aug 28 12:32:14 2019
# fold 4 train:0.00611 	 valid: 0.08160
#
# Fold 5 started at Wed Aug 28 12:32:22 2019
# fold 5 train:0.00612 	 valid: 0.08219
#
# Fold 6 started at Wed Aug 28 12:32:32 2019
# fold 6 train:0.00613 	 valid: 0.08164
#
# CV mean score    : 0.0813, std: 0.0012.
# kaggle mean score: -2.5094
#
#
# ===== finish =====
# CV mean score(group log mae): -1.7903
# CPU times: user 15h 4min 54s, sys: 23min 12s, total: 15h 28min 7s
# Wall time: 34min 33s

# %% [markdown]
# # Save

# %% [markdown]
# **submission**

# %%
# path_submittion = './output/' + 'nb{}_submission_lgb_{}.csv'.format(nb, metric)
path_submittion = f'../output/nb{nb}_stack_submission_{model_name}_{metric :.5f}.csv'
print(f'save pash: {path_submittion}')
# Out:
# save pash: ../output/nb96_stack_submission_extra_trees_regressor_-1.79030.csv

# %%
submittion = pd.read_csv('../input/champs-scalar-coupling/sample_submission.csv')
# submittion = pd.read_csv('./input/champs-scalar-coupling/sample_submission.csv')[::100]
submittion['scalar_coupling_constant'] = prediction
if isSmallSet:
    pass
else:
    submittion.to_csv(path_submittion, index=False)

# %% [markdown]
# ---
# **result**

# %%
path_oof = f'../output/nb{nb}_stack_oof_{model_name}_{metric :.5f}.csv'
print(f'save pash: {path_oof}')
# Out:
# save pash: ../output/nb96_stack_oof_extra_trees_regressor_-1.79030.csv

# %%
oof = pd.DataFrame(X_short['oof'])
if isSmallSet:
    pass
else:
    oof.to_csv(path_oof, index=False)

# %% [markdown]
# # analysis

# %%
plot_data = pd.DataFrame(y)
plot_data.index.name = 'id'
plot_data['yhat'] = X_short['oof'].values
plot_data['type'] = type_train

def plot_oof_preds(ctype, llim, ulim):
        plt.figure(figsize=(6,6))
        sns.scatterplot(x='scalar_coupling_constant',y='yhat',
                        data=plot_data.loc[plot_data['type']==ctype,
                        ['scalar_coupling_constant', 'yhat']]);
        plt.xlim((llim, ulim))
        plt.ylim((llim, ulim))
        plt.plot([llim, ulim], [llim, ulim])
        plt.xlabel('scalar_coupling_constant')
        plt.ylabel('predicted')
        plt.title(f'{ctype}', fontsize=18)
        plt.show()

plot_oof_preds('1JHC', 0, 250)
plot_oof_preds('1JHN', 0, 100)
plot_oof_preds('2JHC', -50, 50)
plot_oof_preds('2JHH', -50, 50)
plot_oof_preds('2JHN', -10, 25)
plot_oof_preds('3JHC', -25, 60)
plot_oof_preds('3JHH', -20, 20)
plot_oof_preds('3JHN', -10, 15)

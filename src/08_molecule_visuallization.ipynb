# %% [markdown]
# # Introduction
# - 分子を `acs`を使って可視化
# - URL: https://www.kaggle.com/kernels/scriptcontent/15173624/download

# %% [markdown]
# # Import everything I nead :)

# %% [raw]
# !pip3 install --user ase

# %% [raw]
# !pip3 install --user networkx

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from ase import Atoms
import ase.visualize
import networkx as nx

# %% [markdown]
# # Data Preparation

# %%
path = './data/champs-scalar-coupling/structures.csv'
df_struct = pd.read_csv(path)

path = './data/champs-scalar-coupling/train.csv'
df_train = pd.read_csv(path)

# %% [markdown]
# # data visualization

# %%
df_struct.head(10)
# Out:
#       molecule_name  atom_index atom         x         y         z
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
# 5  dsgdb9nsd_000002           0    N -0.040426  1.024108  0.062564
# 6  dsgdb9nsd_000002           1    H  0.017257  0.012545 -0.027377
# 7  dsgdb9nsd_000002           2    H  0.915789  1.358745 -0.028758
# 8  dsgdb9nsd_000002           3    H -0.520278  1.343532 -0.775543
# 9  dsgdb9nsd_000003           0    O -0.034360  0.977540  0.007602

# %%
# Select a molecule
random_molecule = random.choice(df_struct['molecule_name'].unique())
molecule = df_struct[df_struct['molecule_name'] == random_molecule]
display(molecule)
# Out:
#            molecule_name  atom_index atom         x         y         z
# 245832  dsgdb9nsd_015473           0    O -0.083386  0.065901  0.320475
# 245833  dsgdb9nsd_015473           1    C -0.105194  1.258943  0.215189
# 245834  dsgdb9nsd_015473           2    C -1.350355  2.150734  0.075749
# 245835  dsgdb9nsd_015473           3    N -0.884363  3.513918 -0.183782
# 245836  dsgdb9nsd_015473           4    C  0.452747  3.598860  0.421798
# 245837  dsgdb9nsd_015473           5    C  1.123250  2.216198  0.194573
# 245838  dsgdb9nsd_015473           6    C  2.182414  1.854511  1.111668
# 245839  dsgdb9nsd_015473           7    C  3.050462  1.578439  1.895533
# 245840  dsgdb9nsd_015473           8    H -2.022944  1.778360 -0.700485
# 245841  dsgdb9nsd_015473           9    H -1.897787  2.104605  1.028324
# 245842  dsgdb9nsd_015473          10    H -0.802601  3.653245 -1.185810
# 245843  dsgdb9nsd_015473          11    H  1.021965  4.424723 -0.007349
# 245844  dsgdb9nsd_015473          12    H  0.354385  3.780099  1.498230
# 245845  dsgdb9nsd_015473          13    H  1.498096  2.180195 -0.840247
# 245846  dsgdb9nsd_015473          14    H  3.819413  1.323101  2.581811

# %%
# Get atomic coordinates
atoms = molecule.iloc[:, 3:].values
print(atoms)
# Out:
# [[-0.08338637  0.0659007   0.32047505]
#  [-0.10519409  1.25894312  0.21518912]
#  [-1.35035467  2.15073436  0.07574886]
#  [-0.8843634   3.51391805 -0.18378233]
#  [ 0.4527466   3.59885976  0.42179793]
#  [ 1.12324966  2.21619768  0.19457346]
#  [ 2.18241391  1.85451082  1.11166795]
#  [ 3.05046236  1.57843935  1.89553322]
#  [-2.0229438   1.77835952 -0.70048534]
#  [-1.89778737  2.10460533  1.02832427]
#  [-0.80260117  3.65324485 -1.18580968]
#  [ 1.02196509  4.42472261 -0.00734897]
#  [ 0.35438482  3.78009899  1.49823042]
#  [ 1.49809554  2.18019491 -0.84024725]
#  [ 3.81941307  1.32310076  2.5818109 ]]

# %%
# Get atomic symbols
symbols = molecule.iloc[:, 2].values
print(symbols)
# Out:
# ['O' 'C' 'C' 'N' 'C' 'C' 'C' 'C' 'H' 'H' 'H' 'H' 'H' 'H' 'H']

# %%
system = Atoms(positions=atoms, symbols=symbols)

ase.visualize.view(system, viewer="x3d")
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#
#    <Scene>
#
#     <Transform translation="-0.08 0.07 0.32">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.11 1.26 0.22">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.35 2.15 0.08">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.88 3.51 -0.18">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.45 3.60 0.42">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.12 2.22 0.19">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.18 1.85 1.11">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.05 1.58 1.90">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.02 1.78 -0.70">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.90 2.10 1.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.80 3.65 -1.19">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.02 4.42 -0.01">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.35 3.78 1.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.50 2.18 -0.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.82 1.32 2.58">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %% [markdown]
# # Summary

# %%
def view(molecule):
    # Select a molecule
    mol = df_struct[df_struct['molecule_name'] == molecule]
    
    # Get atomic coordinates
    xcart = mol.iloc[:, 3:].values
    
    # Get atomic symbols
    symbols = mol.iloc[:, 2].values
    
    # Display molecule
    system = Atoms(positions=xcart, symbols=symbols)
    print('Molecule Name: %s.' %molecule)
    return ase.visualize.view(system, viewer="x3d")

random_molecule = random.choice(df_struct['molecule_name'].unique())
view(random_molecule)
# Out:
# Molecule Name: dsgdb9nsd_101759.
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#
#    <Scene>
#
#     <Transform translation="0.10 1.39 -0.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.01 -0.08 0.05">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.09 -0.66 1.17">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.71">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.02 -0.79 -1.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.09 -2.22 -0.98">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.05 -2.76 -2.41">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.15 -2.35 -3.07">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.04 -4.28 -2.46">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.03 -4.74 -3.79">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.66">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.03 1.60 -0.79">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.72 1.71 -0.90">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.09 1.98 0.66">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.07 0.02 1.93">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.76 -2.58 -0.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.01 -2.50 -0.47">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.93 -2.39 -2.96">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.19 -1.39 -3.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.80 -4.66 -1.86">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.97 -4.68 -2.03">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.75 -4.24 -4.20">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %% [markdown]
# ---
# **check coupling constant**

# %%
selected_idx =  df_train['molecule_name']==random_molecule
print(random_molecule)
print(len(selected_idx))
select_df_train = df_train[selected_idx]
select_df_train
# Out:
# dsgdb9nsd_055240
# 4658147
#               id     molecule_name  atom_index_0  atom_index_1  type  \
# 1697679  1697679  dsgdb9nsd_055240             9             0  1JHN
# 1697680  1697680  dsgdb9nsd_055240             9             1  2JHC
# 1697681  1697681  dsgdb9nsd_055240             9             3  3JHC
# 1697682  1697682  dsgdb9nsd_055240             9            10  2JHH
# 1697683  1697683  dsgdb9nsd_055240            10             0  1JHN
# 1697684  1697684  dsgdb9nsd_055240            10             1  2JHC
# 1697685  1697685  dsgdb9nsd_055240            10             3  3JHC
# 1697706                  7.738380
# 1697707                  0.276819
# 1697708                  8.409710
# 1697709                  5.963380
# 1697710                  0.070745
# 1697711                 90.243900
# 1697712                 -2.997400
# 1697713                -15.498900
# 1697714                  0.082750
# 1697715                 -1.100760
# 1697716                 85.845800
# 1697717                 -4.905900

# %%
print(select_df_train['atom_index_0'].unique())
print(select_df_train['atom_index_1'].unique())
# Out:
# [ 9 10 11 12 13 14 15]
# [ 0  1  3 10  4  5  6 12 13 14 15]

# %% [markdown]
# ---
# **structure**

# %%
selected_idx = df_struct['molecule_name'] == random_molecule
    
# Get atomic symbols
symbols = df_struct[selected_idx]
symbols
# Out:
#            molecule_name  atom_index atom         x         y         z
# 896197  dsgdb9nsd_055240           0    N  0.647517 -0.319263  0.491370
# 896198  dsgdb9nsd_055240           1    C -0.217007  0.206028 -0.409664
# 896199  dsgdb9nsd_055240           2    O  0.067337  1.061718 -1.225247
# 896200  dsgdb9nsd_055240           3    C -1.652756 -0.343492 -0.329518
# 896201  dsgdb9nsd_055240           4    C -2.196456 -0.773423 -1.704721
# 896202  dsgdb9nsd_055240           5    C -1.904889 -2.276444 -1.715053
# 896203  dsgdb9nsd_055240           6    C -1.840747 -2.655200 -0.240899
# 896204  dsgdb9nsd_055240           7    O -1.860131 -3.736319  0.264612
# 896205  dsgdb9nsd_055240           8    O -1.731060 -1.509796  0.510214
# 896206  dsgdb9nsd_055240           9    H  1.588331  0.036807  0.524665
# 896207  dsgdb9nsd_055240          10    H  0.341302 -1.003654  1.161820
# 896208  dsgdb9nsd_055240          11    H -2.266491  0.432984  0.135050
# 896209  dsgdb9nsd_055240          12    H -3.272381 -0.588501 -1.754218
# 896210  dsgdb9nsd_055240          13    H -1.709992 -0.209270 -2.499759
# 896211  dsgdb9nsd_055240          14    H -2.648411 -2.888263 -2.226847
# 896212  dsgdb9nsd_055240          15    H -0.929358 -2.507178 -2.158190

# %% [markdown]
# ---

# %% [markdown]
# **相互作用をする原子の数を調べる**

# %%
atom_num = 10                                          # この数字がなんの原子にあたるかは、上のstructureを見よ 
idx = select_df_train['atom_index_0'] == atom_num
select_df_train['atom_index_1'][idx]
# Out:
# 1697683    0
# 1697684    1
# 1697685    3
# Name: atom_index_1, dtype: int64

# %% [markdown]
# ---> この数は、上の3D図と見比べればわかるが、触れている数に相当する
# ---> となると、

# %% [markdown]
# ---

# %% [markdown]
# ---> 上記2つのdataframeについて
# ---> 上のデータフレームは、カップリングコンスタントの組み合わせが書かれている
# ---> 下のデータフレームは構造について。
# ---> 上の表の、atom_index0は、Hのみを示している。
# ---> atom_index_0, 1 双方にO(酸素)がないのは、$\gamma$が小さいからである。
# ---> 相互作用の数は、H,N,O間の数だけあるはず
